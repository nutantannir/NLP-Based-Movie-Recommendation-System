# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\nutan\anaconda3\lib\site-packages (2.32.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nutan\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nutan\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nutan\anaconda3\lib\site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nutan\anaconda3\lib\site-packages (from requests) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # PART 1: THIS SECTION OF THE CODE AIMS AT FETCHING THE MOVIE METADATA FROM OMDB API FROM THE GIVEN LIST OF MOVIE TITLES.

# %%
import pandas as pd
import requests
import time

# THIS FUCTION IS TO FETCH MOVIE INFORMATION BY TITLE AND IF AVAILABLE BY YEAR
def get_omdb_movie_data(movie_title, movie_year, api_key):
    if movie_year and not pd.isna(movie_year):  # Check if year is provided
        movie_year = str(int(movie_year))
        url = f'http://www.omdbapi.com/?apikey={api_key}&t={movie_title}&y={movie_year}'
    else:
        url = f'http://www.omdbapi.com/?apikey={api_key}&t={movie_title}'
    
    try:
        # SENDING REQUEST TO API
        response = requests.get(url, timeout=10)
        
        # CHECK TO SEE IF RESPONSE WAS SUCCESSFULL
        if response.status_code == 200:
            movie_data = response.json()
            
            if movie_data.get("Response") == "True":
                return {
                    "Title": movie_data.get("Title", "N/A"),
                    "Year": movie_data.get("Year", "N/A"),
                    "Rated": movie_data.get("Rated", "N/A"),
                    "Released": movie_data.get("Released", "N/A"),
                    "Runtime": movie_data.get("Runtime", "N/A"),
                    "Genre": movie_data.get("Genre", "N/A"),
                    "Director": movie_data.get("Director", "N/A"),
                    "Actors": movie_data.get("Actors", "N/A"),
                    "Plot": movie_data.get("Plot", "N/A"),
                    "IMDb Rating": movie_data.get("imdbRating", "N/A")
                }
            else:
                return None
        else:
            return None
    except Exception as e:
        return None
        
# READING THE CSV FILE WITH MOVIE TITLES AND YEARS
try:
    my_movie_list_df = pd.read_csv("C:/Users/Nutan/Downloads/movies.csv", encoding="ISO-8859-1")
except FileNotFoundError:
    print("CSV file not found. Please check the file path and try again.")
    exit()

# INITIALIZING API KEY
API_KEY = "6f5fdbed"

# INITIALIZING EMPTY LIST TO STORE MOVIE METADATA     
my_movie_dataset = []

# LOOPING THROUGH THE MOVIES FROM CSV FILE AND FETCHING THE DETAILS FOR EACH MOVIE
for index, row in my_movie_list_df.iterrows():
    movie_title = row['Title'] 
    movie_year = row.get('Year', None) 
    
    # FETCHING MOVIE DATA
    movie_data = get_omdb_movie_data(movie_title, movie_year, API_KEY)
    
    if movie_data:  # ONLY ADDING MOVIE IF THE DATA WAS FETCHED SUCCESSFULLY 
        my_movie_dataset.append(movie_data)
    
    # SINCE I AM FETCHING DATA FOR 1500 MOVIE TITLES, I AM SHOWING THE PROGESS AFTER EVERY 100 MOVIES HAVE BEEN FETCHED SUCCESSFULLY 
    if (index + 1) % 100 == 0:
        print(f"Processed {index + 1} movies...")

    time.sleep(1)  # PAUSING HERE TO AVOID HITTING RATE LIMIT OF THE API

# CONVERTING THE MOVIE METADATA OBTAINED INTO A PANDAS DATAFRAME
df = pd.DataFrame(my_movie_dataset)

# SAVING THE DATAFRAME TO A CSV FILE 
df.to_csv('MY_omdb_movie_dataset.csv', index=False) 

print("Movie dataset has been created and saved to 'MY_omdb_movie_dataset.csv'")

df.head(10)
# Out:
# Processed 100 movies...
# Processed 200 movies...
# Processed 300 movies...
# Processed 400 movies...
# Processed 500 movies...
# Processed 600 movies...
# Processed 700 movies...
# Processed 800 movies...
# Processed 900 movies...
# Processed 1000 movies...
# Processed 1100 movies...
# Processed 1200 movies...
# Processed 1300 movies...
# Processed 1400 movies...
# Processed 1500 movies...
# Movie dataset has been created and saved to 'MY_omdb_movie_dataset.csv'
#                       Title  Year  Rated     Released  Runtime  \
# 0  The Shawshank Redemption  1994      R  14 Oct 1994  142 min
# 1              Forrest Gump  1994  PG-13  06 Jul 1994  142 min
# 2          Schindler's List  1993      R  04 Feb 1994  195 min
# 3             The Godfather  1972      R  24 Mar 1972  175 min
# 4            The Green Mile  1999      R  10 Dec 1999  189 min
# 5         Good Will Hunting  1997      R  09 Jan 1998  126 min
# 6          A Beautiful Mind  2001  PG-13  04 Jan 2002  135 min
# 7       Saving Private Ryan  1998      R  24 Jul 1998  169 min
# 8  The Pursuit of Happyness  2006  PG-13  15 Dec 2006  117 min
# 9               The Pianist  2002      R  28 Mar 2003  150 min
#
#                        Genre              Director  \
# 0                      Drama        Frank Darabont
# 1             Drama, Romance       Robert Zemeckis
# 2  Biography, Drama, History      Steven Spielberg
# 3               Crime, Drama  Francis Ford Coppola
# 4      Crime, Drama, Fantasy        Frank Darabont
# 5             Drama, Romance          Gus Van Sant
# 6  Biography, Drama, Mystery            Ron Howard
# 7                 Drama, War      Steven Spielberg
# 8           Biography, Drama      Gabriele Muccino
# 9    Biography, Drama, Music        Roman Polanski
#
#                                            Actors  \
# 0         Tim Robbins, Morgan Freeman, Bob Gunton
# 1            Tom Hanks, Robin Wright, Gary Sinise
# 2        Liam Neeson, Ralph Fiennes, Ben Kingsley
# 3            Marlon Brando, Al Pacino, James Caan
# 4   Tom Hanks, Michael Clarke Duncan, David Morse
# 5         Robin Williams, Matt Damon, Ben Affleck
# 6     Russell Crowe, Ed Harris, Jennifer Connelly
# 7             Tom Hanks, Matt Damon, Tom Sizemore
# 8        Will Smith, Thandiwe Newton, Jaden Smith
# 9  Adrien Brody, Thomas Kretschmann, Frank Finlay
#
#                                                 Plot IMDb Rating
# 0  A banker convicted of uxoricide forms a friend...         9.3
# 1  The history of the United States from the 1950...         8.8
# 2  In German-occupied Poland during World War II,...         9.0
# 3  The aging patriarch of an organized crime dyna...         9.2
# 4  A tale set on death row, where gentle giant Jo...         8.6
# 5  Will Hunting, a janitor at MIT, has a gift for...         8.3
# 6  A mathematical genius, John Nash made an aston...         8.2
# 7  Following the Normandy Landings, a group of U....         8.6
# 8  A struggling salesman takes custody of his son...         8.0
# 9  During WWII, acclaimed Polish musician Wladysl...         8.5

# %% [markdown]
# ## PREPROCESSING THE PLOT FOR NLP COLUMNS

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import re

# DOWNLOADING NLTK RESOURCES 
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# LOADING MOVIES DATASET
movies_df = pd.read_csv("MY_omdb_movie_dataset.csv")

# INITIALIZING NLTK TOOLS
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# FUNCTION TO PREPROCESS MOVIE PLOT
def preprocess_movie_plot(plot):
    #CHECK IF THE PLOT IS NOT A STRING
    if not isinstance(plot, str):
        return "" 
        
    # STEP1: LOWERCASING
    plot = plot.lower()

    # STEP 2: REMOVING SPECIAL CHARACTERS( RETAINS ONLY WORDS AND SPACES)
    plot = re.sub(r'[^a-z\s]', '', plot)

    # STEP 3: TOKENIZING
    tokens = word_tokenize(plot)

    # STEP 4: REMOVING STOP WORDS
    filtered_tokens = [word for word in tokens if word not in stop_words]

    # STEP 5 : LEMMATIZING
    lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]

    # JOINGING TOKENS BACK TO A SINGLE STRING
    return ' '.join(lemmatized_tokens)

# APPLYING PREPROCESSING TO THE 'Plot' COLUMN
movies_df['Processed_Plot'] = movies_df['Plot'].apply(preprocess_movie_plot)

# SAVING THE PREPROCESSED PLOT COLUMN TO CSV FILE
movies_df.to_csv("MY_omdb_movie_dataset.csv", index=False)

print("Preprocessing complete. First 5 processed plots:")
movies_df[['Title', 'Plot', 'Processed_Plot']].head()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Nutan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Nutan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Nutan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Preprocessing complete. First 5 processed plots:
#                       Title  \
# 0  The Shawshank Redemption
# 1              Forrest Gump
# 2          Schindler's List
# 3             The Godfather
# 4            The Green Mile
#
#                                                 Plot  \
# 0  A banker convicted of uxoricide forms a friend...
# 1  The history of the United States from the 1950...
# 2  In German-occupied Poland during World War II,...
# 3  The aging patriarch of an organized crime dyna...
# 4  A tale set on death row, where gentle giant Jo...
#
#                                       Processed_Plot
# 0  banker convicted uxoricide form friendship qua...
# 1  history united state unfolds perspective alaba...
# 2  germanoccupied poland world war ii industriali...
# 3  aging patriarch organized crime dynasty transf...
# 4  tale set death row gentle giant john coffey po...

# %%
pip install textblob
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: textblob in c:\users\nutan\anaconda3\lib\site-packages (0.18.0.post0)
# Requirement already satisfied: nltk>=3.8 in c:\users\nutan\anaconda3\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\nutan\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (8.1.7)
# Requirement already satisfied: joblib in c:\users\nutan\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\nutan\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\nutan\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (4.66.4)
# Requirement already satisfied: colorama in c:\users\nutan\anaconda3\lib\site-packages (from click->nltk>=3.8->textblob) (0.4.6)

# %% [markdown]
# # PART 2: SENTIMENT ANALYSIS OF THE MOVIE PLOTS

# %%
from textblob import TextBlob

movies_df = pd.read_csv("MY_omdb_movie_dataset.csv")

# FUNCTION TO ANALYSE SENTIMENT AND SENTIMENT SCORE OF MOVIE PLOTS 
def analyze_plot_sentiment(plot):
    blob = TextBlob(plot)
    polarity = blob.sentiment.polarity
    sentiment = "Positive" if polarity > 0 else "Negative" if polarity < 0 else "Neutral"
    return sentiment, polarity

# APPLYING SENTIMENT ANALYSIS TO THE PLOT COLUMN 
movies_df['Sentiment'], movies_df['Sentiment Score'] = zip(*movies_df['Processed_Plot'].apply(lambda x: analyze_plot_sentiment(x) if isinstance(x, str) else ("Neutral", 0)))

movies_df.to_csv('MY_omdb_movie_dataset.csv', index=False)

# DISPLAYING THE UPDATED DATAFRAME WITH SENTIMENT AND SENTIMENT SCORE COLUMNS
movies_df[['Title', 'Processed_Plot', 'Sentiment', 'Sentiment Score']].head(10)
# Out:
#                       Title  \
# 0  The Shawshank Redemption
# 1              Forrest Gump
# 2          Schindler's List
# 3             The Godfather
# 4            The Green Mile
# 5         Good Will Hunting
# 6          A Beautiful Mind
# 7       Saving Private Ryan
# 8  The Pursuit of Happyness
# 9               The Pianist
#
#                                       Processed_Plot Sentiment  \
# 0  banker convicted uxoricide form friendship qua...   Neutral
# 1  history united state unfolds perspective alaba...   Neutral
# 2  germanoccupied poland world war ii industriali...   Neutral
# 3  aging patriarch organized crime dynasty transf...   Neutral
# 4  tale set death row gentle giant john coffey po...  Positive
# 5  hunting janitor mit gift mathematics need help...   Neutral
# 6  mathematical genius john nash made astonishing...  Positive
# 7  following normandy landing group u soldier go ...  Negative
# 8  struggling salesman take custody son he poised...  Positive
# 9  wwii acclaimed polish musician wladyslaw face ...  Negative
#
#    Sentiment Score
# 0         0.000000
# 1         0.000000
# 2         0.000000
# 3         0.000000
# 4         0.066667
# 5         0.000000
# 6         0.220000
# 7        -0.125000
# 8         0.100000
# 9        -0.150000

# %% [markdown]
# # PART 3: KEYWORD EXTRACTION USING KeyBERT

# %%
from keybert import KeyBERT
from sentence_transformers import SentenceTransformer
import pandas as pd

movies_df = pd.read_csv("MY_omdb_movie_dataset.csv")

# INITIALIZING THE KeyBERT MODEL (THIS MODEL USES BERT EMBEDDINGS INTERNALLY)
model = KeyBERT('all-MiniLM-L6-v2')

# FUCNTION TO EXTRACT KEYWORDS USING KeyBERT
def extracting_keywords_with_keybert(text, top_n=5):
    keywords = model.extract_keywords(text, top_n=top_n)
    return ", ".join([kw[0] for kw in keywords])

# APPLYING THE KeyBERT KEYWORD EXTRACTION TO MOVIE PLOT COLUMN 
movies_df['Extracted_Keywords'] = movies_df['Processed_Plot'].fillna("").apply(extracting_keywords_with_keybert)

# SAVING THE COLUMN TO THE CSV FILE
movies_df.to_csv("MY_omdb_movie_dataset.csv", index=False)

# DISPLAYING THE EXTRACTED KEYWORDS COLUMN
movies_df[['Title', 'Processed_Plot', 'Extracted_Keywords']].head(10)
# Out:
# WARNING:tensorflow:From C:\Users\Nutan\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#                       Title  \
# 0  The Shawshank Redemption
# 1              Forrest Gump
# 2          Schindler's List
# 3             The Godfather
# 4            The Green Mile
# 5         Good Will Hunting
# 6          A Beautiful Mind
# 7       Saving Private Ryan
# 8  The Pursuit of Happyness
# 9               The Pianist
#
#                                       Processed_Plot  \
# 0  banker convicted uxoricide form friendship qua...
# 1  history united state unfolds perspective alaba...
# 2  germanoccupied poland world war ii industriali...
# 3  aging patriarch organized crime dynasty transf...
# 4  tale set death row gentle giant john coffey po...
# 5  hunting janitor mit gift mathematics need help...
# 6  mathematical genius john nash made astonishing...
# 7  following normandy landing group u soldier go ...
# 8  struggling salesman take custody son he poised...
# 9  wwii acclaimed polish musician wladyslaw face ...
#
#                                   Extracted_Keywords
# 0   convict, convicted, innocence, uxoricide, banker
# 1              alabama, reunited, iq, state, history
# 2     schindler, nazi, oskar, jewish, germanoccupied
# 3     dynasty, clandestine, empire, patriarch, crime
# 4                   coffey, tale, john, giant, death
# 5  mathematics, janitor, psychologist, gift, hunting
# 6       nash, mathematical, discovery, john, journey
# 7     paratrooper, normandy, soldier, landing, enemy
# 8       salesman, custody, son, career, lifechanging
# 9          wladyslaw, warsaw, polish, wwii, musician
