# %% [markdown]
# # PART 1:THIS SECTION AIMS TO FETCH SONG METADATA FOR A LIST OF SONGS

# %%
#fetch spotify metadata
import pandas as pd
import requests
import base64
import time
import os

# FUNCTION TO GET SPOTIFY API ACCESS TOKEN
def get_my_spotify_token(client_id, client_secret):
    url = "https://accounts.spotify.com/api/token"
    headers = {
        "Authorization": "Basic " + base64.b64encode(f"{client_id}:{client_secret}".encode()).decode()
    }
    data = {"grant_type": "client_credentials"}
    
    response = requests.post(url, headers=headers, data=data)
    if response.status_code == 200:
        return response.json()["access_token"]
    else:
        raise Exception(f"Failed to retrieve token: {response.status_code}, {response.text}")

# FUNCTION TO FETCH METADATA FROM APOTIFY API WITH RATE LIMITING FUNCTIONALITY
def get_my_spotify_metadata(track_name, artist_name, access_token):
    search_url = f"https://api.spotify.com/v1/search?q=track:{track_name}%20artist:{artist_name}&type=track&limit=1"
    headers = {"Authorization": f"Bearer {access_token}"}
    
    while True:
        response = requests.get(search_url, headers=headers)
        
        if response.status_code == 200:
            data = response.json()
            if data['tracks']['items']:
                track = data['tracks']['items'][0]
                # EXTRACTING ONLY THE RELEASE YEAR FROM RELEASE DATE
                release_date = track.get("album")["release_date"]
                release_year = release_date.split("-")[0] if release_date else None
                return {
                    "Track Name": track.get("name"),
                    "Artist": track.get("artists")[0]["name"],
                    "Album": track.get("album")["name"],
                    "Release Year": release_year,  
                    "Track Popularity": track.get("popularity")
                }
            else:
                print(f"Track '{track_name}' by {artist_name} not found.")
                return None
        elif response.status_code == 429:  # Rate limit hit
            retry_after = int(response.headers.get("Retry-After", 1))
            print(f"Rate limit hit. Retrying after {retry_after} seconds...")
            time.sleep(retry_after)
        else:
            print(f"Error: {response.status_code}, {response.text}")
            return None

# LOADING THE SONG LIST FROM CSV FILE
song_list_df = pd.read_csv("C:/Users/Nutan/Downloads/songs.csv", encoding="ISO-8859-1")  

# INITIALIZING SPOTIFY API CREDENTIALS
SPOTIFY_CLIENT_ID = "584b24e6cc7d437cb9fe17ae417796cf"
SPOTIFY_CLIENT_SECRET = "079a6905fe0b4f0aa57170b94af24f14"

# GETTING THE SPOTIFY ACCESS TOKEN
spotify_access_token = get_my_spotify_token(SPOTIFY_CLIENT_ID, SPOTIFY_CLIENT_SECRET)

# SETTING UP BATCH PROCESSING
batch_size = 300  
output_file = "SPOTIFY_GENIUS_SONGS_DATASET.csv"
my_spotify_data = []

# RESUME FUNCTIONALITY : CHECKING IF THE OUTPUT FILE ALREADY EXISTS
if os.path.exists(output_file):
    my_spotify_data = pd.read_csv(output_file).to_dict(orient="records")
    processed_tracks = {(item["Track Name"], item["Artist"]) for item in my_spotify_data}
else:
    processed_tracks = set()

# PROCESSING THE SONGS IN BATCHES TO AVOID RATE LIMIT
total_tracks = len(song_list_df)
for start_idx in range(0, total_tracks, batch_size):
    end_idx = min(start_idx + batch_size, total_tracks)
    batch = song_list_df.iloc[start_idx:end_idx]
    print(f"Processing batch {start_idx + 1} to {end_idx} of {total_tracks}...")

    for _, row in batch.iterrows():
        track_name = row['Track Name']
        artist_name = row['Artist']

        # SKIPPING ALREADY PROCESSED TRACKS
        if (track_name, artist_name) in processed_tracks:
            continue

        # FETCHING THE SONG METADATA FROM SPOTIFY
        song_metadata = get_my_spotify_metadata(track_name, artist_name, spotify_access_token)

        if song_metadata:
            my_spotify_data.append(song_metadata)
            processed_tracks.add((track_name, artist_name))
        else:
            print(f"Metadata not found for {track_name} by {artist_name}")

        # ADDING A DELAY BETWEEN REQUESTS
        time.sleep(0.1)

    # SAVING PROGESS AFTER EVERY BATCH
    pd.DataFrame(my_spotify_data).to_csv(output_file, index=False)
    print(f"Batch {start_idx + 1} to {end_idx} saved to {output_file}.")

    # PAUSING BETWEEN BATCHES
    print("Pausing for 30 seconds between batches...")
    time.sleep(30)

# SAVING ALL DATA TO CSV FILE
pd.DataFrame(my_spotify_data).to_csv(output_file, index=False)

print(f"All batches processed. Final dataset saved to {output_file}.")
# Out:
# Processing batch 1 to 300 of 1494...
# Batch 1 to 300 saved to SPOTIFY_GENIUS_SONGS_DATASET.csv.
# Pausing for 30 seconds between batches...
# Processing batch 301 to 600 of 1494...
# Batch 301 to 600 saved to SPOTIFY_GENIUS_SONGS_DATASET.csv.
# Pausing for 30 seconds between batches...
# Processing batch 601 to 900 of 1494...
# Batch 601 to 900 saved to SPOTIFY_GENIUS_SONGS_DATASET.csv.
# Pausing for 30 seconds between batches...
# Processing batch 901 to 1200 of 1494...
# Batch 901 to 1200 saved to SPOTIFY_GENIUS_SONGS_DATASET.csv.
# Pausing for 30 seconds between batches...
# Processing batch 1201 to 1494 of 1494...
# Track 'One Way Up' by Fredde Le Grand not found.
# Metadata not found for One Way Up by Fredde Le Grand
# Batch 1201 to 1494 saved to SPOTIFY_GENIUS_SONGS_DATASET.csv.
# Pausing for 30 seconds between batches...
# All batches processed. Final dataset saved to SPOTIFY_GENIUS_SONGS_DATASET.csv.

# %%
#DISPLAYING ABOVE CREATED CSV FILE
fetched_songs= pd.read_csv("SPOTIFY_GENIUS_SONGS_DATASET.csv")
fetched_songs.head(10)
# Out:
#                                           Track Name              Artist  \
# 0                             Oops!...I Did It Again      Britney Spears
# 1  Bye Bye Bye - From Deadpool and Wolverine Soun...              *NSYNC
# 2                                  What a Girl Wants  Christina Aguilera
# 3                                              Candy         Mandy Moore
# 4                                  Shape of My Heart     Backstreet Boys
# 5                       I Think I'm in Love with You     Jessica Simpson
# 6                                              Lucky      Britney Spears
# 7                 Give Me Just One Night (Una Noche)                 98º
# 8                                              Reach              S Club
# 9                           Halfway Around The World             A*Teens
#
#                                    Album  Release Year  Track Popularity
# 0                Oops!... I Did It Again          2000                79
# 1                    No Strings Attached          2000                85
# 2  Christina Aguilera (Expanded Edition)          1999                64
# 3                                So Real          1999                50
# 4                           Black & Blue          2000                70
# 5                           Sweet Kisses          1999                47
# 6                Oops!... I Did It Again          2000                64
# 7                             Revelation          2000                41
# 8                                    "7"          2000                52
# 9                            Teen Spirit          2001                36

# %% [markdown]
# # PART 2: THIS SECTIONS AIMS AT FETCHING THE LYRICS OF SONGS USING THE GENIUS API

# %%
# fetch lyrics from genius using fuzzy match
import lyricsgenius
import pandas as pd
import time
import os
from rapidfuzz import fuzz, process  # For fuzzy matching

# INITIALIZING GENIUS WITH ACCESS TOKEN
GENIUS_ACCESS_TOKEN = "E2YECdbQN9JzdsNJyftP6-PxA6kG6jzPhWSYceXSZgEi3S1oZVmhjOp6jSXjMTq5"  
genius = lyricsgenius.Genius(GENIUS_ACCESS_TOKEN)
genius.remove_section_headers = True #THIS REMOVES UNREQUIRED HEADINGS IN LYRICS 

# LOADING THE SPOTIFY METADATA CSV AND THE ORIGINAL SONGS LIST
spotify_df = pd.read_csv("SPOTIFY_GENIUS_SONGS_DATASET.csv")  
original_list_df = pd.read_csv("C:/Users/Nutan/Downloads/songs.csv", encoding="ISO-8859-1")  

# FUNCTION TO NORMALIZE SONG TITLES
def normalize_title(title):
    # Remove "(feat. artist)" or "(with artist)" and any trailing spaces 
    return title.split(" (feat.")[0].split(" (with")[0].strip()


# ENSURING THE LYRICS COLUMN EXISTS IN THE SPOTIFY DATA
if 'Lyrics' not in spotify_df.columns:
    spotify_df['Lyrics'] = ""

# DEFINING THE OUTPUT FILE
output_file = "my_SPOTIFY_GENIUS_SONG_DATASET.csv"

# CHECKING IF THE OUTPUT FILE ALREADY EXISTS FOR RESUME FUNCTIONALITY
if os.path.exists(output_file):
    processed_df = pd.read_csv(output_file)
    processed_tracks = set(zip(processed_df['Track Name'], processed_df['Artist']))
    spotify_df = spotify_df[~spotify_df.set_index(['Track Name', 'Artist']).index.isin(processed_tracks)]
    lyrics_data = processed_df.to_dict(orient="records")  # Load existing data
else:
    lyrics_data = []
    processed_tracks = set()

# FUZZY MATCHING THRESHOLD
# SINCE I ONLY WANT THE TITLE MATCH AND NOT THE ENTIRE TITLE AS PROVIDED BY SPOTIFY, A LOW THRESHOLD OF 10 HAS BEEN CHOSEN
FUZZY_MATCH_THRESHOLD = 10  

# PROCESSING THE SONGS IN BATCHES
batch_size = 100
total_tracks = len(spotify_df)
spotify_df.reset_index(drop=True, inplace=True)

print(f"Total songs to process: {total_tracks}")

for start_idx in range(0, total_tracks, batch_size):
    end_idx = min(start_idx + batch_size, total_tracks)
    batch = spotify_df.iloc[start_idx:end_idx]
    print(f"\nProcessing batch {start_idx + 1} to {end_idx}...")

    for index, row in batch.iterrows():
        track_name = row['Track Name']
        artist_name = row['Artist']

        try:
            # NORMALIZING THE TRACK NAME
            normalized_track_name = normalize_title(track_name)
            # FETCHING LYRICS USING SPOTIFY TITLE
            song = genius.search_song(normalized_track_name, artist_name)
            if song:
                lyrics_data.append({
                    "Track Name": track_name,
                    "Artist": artist_name,
                    "Album": row['Album'],  
                    "Release Year": row['Release Year'],  
                    "Track Popularity": row['Track Popularity'], 
                    "Lyrics": song.lyrics
                })
            else:
                print(f"Lyrics not found for '{track_name}' by {artist_name}. Attempting with original list...")

                # FUZZY MATCHING: FINDS THE BEST MATCH IN THE ORIGINAL LIST 
                artist_matches = original_list_df[
                    original_list_df['Artist'].str.lower() == artist_name.lower()
                ]  # FILTER BY ARTIST
                if not artist_matches.empty:
                    best_match = process.extractOne(
                        track_name,  # SEARCH FOR TRACK NAME 
                        artist_matches['Track Name'],  # COMPARE AGAINST ORIGINAL LIST TRACK NAMES 
                        scorer=fuzz.token_sort_ratio
                    )

                    if best_match and best_match[1] >= FUZZY_MATCH_THRESHOLD:
                        # FUZZY MATCH SUCCESSFUL
                        original_title = best_match[0]
                        print(f"Fuzzy match found: '{original_title}' with score {best_match[1]}")
                        song = genius.search_song(original_title, artist_name)
                        if song:
                            lyrics_data.append({
                                "Track Name": track_name,
                                "Artist": artist_name,
                                "Album": row['Album'],
                                "Release Year": row['Release Year'],
                                "Track Popularity": row['Track Popularity'],
                                "Lyrics": song.lyrics
                            })
                            print(f"Lyrics found using fuzzy match title '{original_title}'.")
                        else:
                            lyrics_data.append({
                                "Track Name": track_name,
                                "Artist": artist_name,
                                "Album": row['Album'],
                                "Release Year": row['Release Year'],
                                "Track Popularity": row['Track Popularity'],
                                "Lyrics": "Lyrics not found"
                            })
                            print(f"Lyrics not found for fuzzy match title '{original_title}'.")
                    else:
                        # FUZZY MATCH FAILED
                        lyrics_data.append({
                            "Track Name": track_name,
                            "Artist": artist_name,
                            "Album": row['Album'],
                            "Release Year": row['Release Year'],
                            "Track Popularity": row['Track Popularity'],
                            "Lyrics": "Lyrics not found"
                        })
                        print(f"No suitable fuzzy match found for '{track_name}' by {artist_name}.")
                else:
                    # NO ARTIST MATCHES FOUND
                    lyrics_data.append({
                        "Track Name": track_name,
                        "Artist": artist_name,
                        "Album": row['Album'],
                        "Release Year": row['Release Year'],
                        "Track Popularity": row['Track Popularity'],
                        "Lyrics": "Lyrics not found"
                    })
                    print(f"No matching artist found in original list for '{track_name}' by {artist_name}.")
        except Exception as e:
            lyrics_data.append({
                "Track Name": track_name,
                "Artist": artist_name,
                "Album": row['Album'],
                "Release Year": row['Release Year'],
                "Track Popularity": row['Track Popularity'],
                "Lyrics": "Error fetching lyrics"
            })
            print(f"Error fetching lyrics for '{track_name}' by {artist_name}: {e}")

        # DELAY TO AVOID RATE LIMITS
        time.sleep(0.5)

    # SAVING PROGESS AFTER EACH BATCH
    pd.DataFrame(lyrics_data).to_csv(output_file, index=False)
    print(f"Batch {start_idx + 1} to {end_idx} processed and saved.")

print("\nAll batches processed. Final dataset saved.")
# Out:
# Total songs to process: 1490
#
# Processing batch 1 to 100...
# Searching for "Oops!...I Did It Again" by Britney Spears...
# Done.
# Searching for "Bye Bye Bye - From Deadpool and Wolverine Soundtrack" by *NSYNC...
# Done.
# Searching for "What a Girl Wants" by Christina Aguilera...
# Done.
# Searching for "Candy" by Mandy Moore...
# Done.
# Searching for "Shape of My Heart" by Backstreet Boys...
# Done.
# Searching for "I Think I'm in Love with You" by Jessica Simpson...
# Done.
# Searching for "Lucky" by Britney Spears...
# Done.
# Searching for "Give Me Just One Night (Una Noche)" by 98º...
# Done.
# Searching for "Reach" by S Club...
# Done.
# Searching for "Halfway Around The World" by A*Teens...
# Done.
# Searching for "Summer Girls" by LFO...
# Done.
# Searching for "He Loves You Not" by Dream...
# Done.
# Searching for "I'm a Slave 4 U" by Britney Spears...
# Done.
# Searching for "Pop" by *NSYNC...
# Done.
# Searching for "Irresistible" by Jessica Simpson...
# Done.
# Searching for "Whenever, Wherever" by Shakira...
# Done.
# Searching for "I Should've Never Let You Go" by Bardot...
# Done.
# Searching for "Don't Stop Movin'" by S Club...
# Done.
# Searching for "My Baby" by Lil' Romeo...
# Done.
# Searching for "All or Nothing" by O-Town...
# Done.
# Searching for "Don't Say You Love Me" by M2M...
# Done.
# Searching for "Ultimate - From "Freaky Friday"/Soundtrack Version" by Lindsay Lohan...
# No results found for: 'Ultimate - From "Freaky Friday"/Soundtrack Version Lindsay Lohan'
# Lyrics not found for 'Ultimate - From "Freaky Friday"/Soundtrack Version' by Lindsay Lohan. Attempting with original list...
# Fuzzy match found: 'Ultimate' with score 27.586206896551722
# Searching for "Ultimate" by Lindsay Lohan...
# Done.
# Lyrics found using fuzzy match title 'Ultimate'.
# Searching for "The Call" by Backstreet Boys...
# Done.
# Searching for "I Must Not Chase the Boys" by Play...
# Done.
# Searching for "A Moment Like This" by Kelly Clarkson...
# Done.
# Searching for "Overprotected - Radio Edit" by Britney Spears...
# No results found for: 'Overprotected - Radio Edit Britney Spears'
# Lyrics not found for 'Overprotected - Radio Edit' by Britney Spears. Attempting with original list...
# Fuzzy match found: 'Overprotected' with score 66.66666666666667
# Searching for "Overprotected" by Britney Spears...
# Done.
# Lyrics found using fuzzy match title 'Overprotected'.
# Searching for "A Thousand Miles" by Vanessa Carlton...
# Error fetching lyrics for 'A Thousand Miles' by Vanessa Carlton: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Complicated" by Avril Lavigne...
# Error fetching lyrics for 'Complicated' by Avril Lavigne: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "With You" by Jessica Simpson...
# Done.
# Searching for "Cry" by Mandy Moore...
# Done.
# Searching for "Just Like a Pill" by P!nk...
# Done.
# Searching for "Girlfriend" by *NSYNC...
# Done.
# Searching for "So Yesterday" by Hilary Duff...
# Done.
# Searching for "Here With Me" by Dido...
# Done.
# Searching for "The Tide Is High - Radio Mix" by Atomic Kitten...
# Done.
# Searching for "Have You Ever" by S Club...
# Done.
# Searching for "Crazy In Love" by Beyoncé...
# Done.
# Searching for "Toxic" by Britney Spears...
# Error fetching lyrics for 'Toxic' by Britney Spears: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Beautiful" by Christina Aguilera...
# Done.
# Searching for "Since U Been Gone" by Kelly Clarkson...
# Done.
# Searching for "Sweetest Sin" by Jessica Simpson...
# Done.
# Searching for "Leave (Get Out)" by JoJo...
# Done.
# Searching for "I'm Like A Bird" by Nelly Furtado...
# Done.
# Searching for "Come Clean" by Hilary Duff...
# Done.
# Searching for "New Direction - Original Mix" by S Club Juniors...
# Done.
# Searching for "Pieces Of Me" by Ashlee Simpson...
# Done.
# Searching for "Some Girls" by Rachel Stevens...
# Done.
# Searching for "Sk8er Boi" by Avril Lavigne...
# Done.
# Searching for "Yeah!" by USHER...
# Done.
# Searching for "This Love" by Maroon 5...
# Done.
# Searching for "Everytime" by Britney Spears...
# Done.
# Searching for "Baby Boy" by Beyoncé...
# Done.
# Searching for "Shadow" by Ashlee Simpson...
# Done.
# Searching for "Fly" by Hilary Duff...
# Done.
# Searching for "Slow" by Kylie Minogue...
# Done.
# Searching for "Fighter" by Christina Aguilera...
# Done.
# Searching for "Left Outside Alone" by Anastacia...
# Done.
# Searching for "Beautiful Soul" by Jesse McCartney...
# Done.
# Searching for "Forever And For Always" by Shania Twain...
# Done.
# Searching for "SexyBack" by Justin Timberlake...
# Done.
# Searching for "SOS" by Rihanna...
# Done.
# Searching for "Hips Don't Lie" by Shakira...
# Error fetching lyrics for 'Hips Don't Lie (feat. Wyclef Jean)' by Shakira: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Ain't No Other Man" by Christina Aguilera...
# Done.
# Searching for "Promiscuous" by Nelly Furtado...
# Done.
# Searching for "Breakaway" by Kelly Clarkson...
# Done.
# Searching for "Who Knew - Edit" by P!nk...
# Done.
# Searching for "Buttons" by The Pussycat Dolls...
# Done.
# Searching for "You're Beautiful" by James Blunt...
# Done.
# Searching for "With Love" by Hilary Duff...
# Done.
# Searching for "Everytime We Touch" by Cascada...
# Done.
# Searching for "Unfaithful" by Rihanna...
# Done.
# Searching for "Gimme More" by Britney Spears...
# Error fetching lyrics for 'Gimme More' by Britney Spears: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "No One" by Alicia Keys...
# Done.
# Searching for "2 Hearts" by Kylie Minogue...
# Done.
# Searching for "What Goes Around.../...Comes Around (Interlude)" by Justin Timberlake...
# Done.
# Searching for "Big Girls Don't Cry (Personal)" by Fergie...
# Done.
# Searching for "Rehab" by Amy Winehouse...
# Done.
# Searching for "Umbrella" by Rihanna...
# Error fetching lyrics for 'Umbrella' by Rihanna: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Dear Mr. President" by P!nk...
# Done.
# Searching for "Stranger" by Hilary Duff...
# Done.
# Searching for "Makes Me Wonder" by Maroon 5...
# Done.
# Searching for "Like You'll Never See Me Again" by Alicia Keys...
# Done.
# Searching for "Inconsolable" by Backstreet Boys...
# Done.
# Searching for "One Love" by Blue...
# Done.
# Searching for "I Kissed A Girl" by Katy Perry...
# Error fetching lyrics for 'I Kissed A Girl' by Katy Perry: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Bleeding Love" by Leona Lewis...
# Done.
# Searching for "Single Ladies (Put a Ring on It)" by Beyoncé...
# Done.
# Searching for "Womanizer" by Britney Spears...
# Done.
# Searching for "Poker Face" by Lady Gaga...
# Done.
# Searching for "Won't Go Home Without You" by Maroon 5...
# Done.
# Searching for "7 Things - Single Version" by Miley Cyrus...
# Done.
# Searching for "Leavin'" by Jesse McCartney...
# Done.
# Searching for "Mercy" by Duffy...
# Done.
# Searching for "Take A Bow" by Rihanna...
# Done.
# Searching for "America" by Razorlight...
# Done.
# Searching for "LoveGame" by Lady Gaga...
# Done.
# Searching for "Love Story" by Taylor Swift...
# Done.
# Searching for "Hot N Cold" by Katy Perry...
# Done.
# Searching for "So What" by P!nk...
# Done.
# Searching for "My Life Would Suck Without You" by Kelly Clarkson...
# Done.
# Batch 1 to 100 processed and saved.
#
# Processing batch 101 to 200...
# Searching for "I Gotta Feeling" by Black Eyed Peas...
# Done.
# Searching for "Party In The U.S.A." by Miley Cyrus...
# Done.
# Searching for "Lovebug" by Jonas Brothers...
# Done.
# Searching for "The Man Who Can't Be Moved" by The Script...
# Done.
# Searching for "Bad Romance" by Lady Gaga...
# Done.
# Searching for "TiK ToK" by Kesha...
# Done.
# Searching for "California Gurls" by Katy Perry...
# Done.
# Searching for "OMG" by USHER...
# Done.
# Searching for "Only Girl (In The World)" by Rihanna...
# Done.
# Searching for "Baby" by Justin Bieber...
# Done.
# Searching for "Airplanes" by B.o.B...
# Done.
# Searching for "Misery" by Maroon 5...
# Done.
# Searching for "Raise Your Glass" by P!nk...
# Done.
# Searching for "Waka Waka (This Time for Africa) [The Official 2010 FIFA World Cup (TM) Song]" by Shakira...
# No results found for: 'Waka Waka (This Time for Africa) [The Official 2010 FIFA World Cup (TM) Song] Shakira'
# Lyrics not found for 'Waka Waka (This Time for Africa) [The Official 2010 FIFA World Cup (TM) Song] (feat. Freshlyground)' by Shakira. Attempting with original list...
# Fuzzy match found: 'Waka Waka' with score 16.666666666666664
# Searching for "Waka Waka" by Shakira...
# Done.
# Lyrics found using fuzzy match title 'Waka Waka'.
# Searching for "Hey, Soul Sister" by Train...
# Done.
# Searching for "Price Tag" by Jessie J...
# Done.
# Searching for "Rolling in the Deep" by Adele...
# Done.
# Searching for "Firework" by Katy Perry...
# Done.
# Searching for "Grenade" by Bruno Mars...
# Done.
# Searching for "Born This Way" by Lady Gaga...
# Done.
# Searching for "Domino" by Jessie J...
# Done.
# Searching for "Give Me Everything" by Pitbull...
# Done.
# Searching for "We Found Love" by Rihanna...
# Done.
# Searching for "Without You" by David Guetta...
# Done.
# Searching for "Moves Like Jagger - Studio Recording From "The Voice" Performance" by Maroon 5...
# Done.
# Searching for "Call Me Maybe" by Carly Rae Jepsen...
# Done.
# Searching for "Super Bass" by Nicki Minaj...
# Done.
# Searching for "Wide Awake" by Katy Perry...
# Done.
# Searching for "We Are Young" by fun....
# Done.
# Searching for "What Makes You Beautiful" by One Direction...
# Done.
# Searching for "Someone Like You" by Adele...
# Done.
# Searching for "Diamonds" by Rihanna...
# Error fetching lyrics for 'Diamonds' by Rihanna: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "This Kiss" by Carly Rae Jepsen...
# Done.
# Searching for "Payphone" by Maroon 5...
# Done.
# Searching for "Locked out of Heaven" by Bruno Mars...
# Done.
# Searching for "Want U Back" by Cher Lloyd...
# Done.
# Searching for "Somebody That I Used To Know" by Gotye...
# Done.
# Searching for "Whistle" by Flo Rida...
# Error fetching lyrics for 'Whistle' by Flo Rida: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Wrecking Ball" by Miley Cyrus...
# Done.
# Searching for "Blurred Lines" by Robin Thicke...
# Done.
# Searching for "Roar" by Katy Perry...
# Done.
# Searching for "Just Give Me a Reason" by P!nk...
# Done.
# Searching for "Royals" by Lorde...
# Done.
# Searching for "Story of My Life" by One Direction...
# Done.
# Searching for "Mirrors" by Justin Timberlake...
# Done.
# Searching for "Can't Hold Us" by Macklemore...
# Done.
# Searching for "When I Was Your Man" by Bruno Mars...
# Done.
# Searching for "Burn" by Ellie Goulding...
# Done.
# Searching for "Wake Me Up" by Avicii...
# Done.
# Searching for "Applause" by Lady Gaga...
# Error fetching lyrics for 'Applause' by Lady Gaga: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "All About That Bass" by Meghan Trainor...
# Done.
# Searching for "Shake It Off" by Taylor Swift...
# Error fetching lyrics for 'Shake It Off' by Taylor Swift: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Sing" by Ed Sheeran...
# Done.
# Searching for "Dark Horse" by Katy Perry...
# Done.
# Searching for "Stay With Me" by Sam Smith...
# Done.
# Searching for "Fancy" by Iggy Azalea...
# Done.
# Searching for "Sugar" by Maroon 5...
# Done.
# Searching for "Problem" by Ariana Grande...
# Done.
# Searching for "Night Changes" by One Direction...
# Done.
# Searching for "Happy - From "Despicable Me 2"" by Pharrell Williams...
# No results found for: 'Happy - From "Despicable Me 2" Pharrell Williams'
# Lyrics not found for 'Happy - From "Despicable Me 2"' by Pharrell Williams. Attempting with original list...
# Fuzzy match found: 'Happy' with score 28.57142857142857
# Searching for "Happy" by Pharrell Williams...
# Done.
# Lyrics found using fuzzy match title 'Happy'.
# Searching for "Blank Space" by Taylor Swift...
# Done.
# Searching for "Boom Clap" by Charli xcx...
# Done.
# Searching for "Bad Blood" by Taylor Swift...
# Done.
# Searching for "Hello" by Adele...
# Done.
# Searching for "What Do You Mean?" by Justin Bieber...
# Done.
# Searching for "Like I'm Gonna Lose You" by Meghan Trainor...
# Done.
# Searching for "Shape of You" by Ed Sheeran...
# Error fetching lyrics for 'Shape of You' by Ed Sheeran: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Love Me Like You Do - From "Fifty Shades Of Grey"" by Ellie Goulding...
# Done.
# Searching for "Rise" by Katy Perry...
# Done.
# Searching for "Drag Me Down" by One Direction...
# Done.
# Searching for "Good For You" by Selena Gomez...
# Done.
# Searching for "Stitches" by Shawn Mendes...
# Done.
# Searching for "Work" by Rihanna...
# Done.
# Searching for "Talking Body" by Tove Lo...
# Done.
# Searching for "Send My Love (To Your New Lover)" by Adele...
# Done.
# Searching for "Million Reasons" by Lady Gaga...
# Done.
# Searching for "Treat You Better" by Shawn Mendes...
# Done.
# Searching for "Chained To The Rhythm" by Katy Perry...
# Done.
# Searching for "Cheap Thrills" by Sia...
# Done.
# Searching for "Dangerous Woman" by Ariana Grande...
# Done.
# Searching for "Love Yourself" by Justin Bieber...
# Error fetching lyrics for 'Love Yourself' by Justin Bieber: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Closer" by The Chainsmokers...
# Error fetching lyrics for 'Closer' by The Chainsmokers: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Into You" by Ariana Grande...
# Error fetching lyrics for 'Into You' by Ariana Grande: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Can't Feel My Face" by The Weeknd...
# Done.
# Searching for "Work from Home" by Fifth Harmony...
# Done.
# Searching for "PILLOWTALK" by ZAYN...
# Done.
# Searching for "Teenage Dream" by Katy Perry...
# Done.
# Searching for "Green Light" by Lorde...
# Done.
# Searching for "24K Magic" by Bruno Mars...
# Done.
# Searching for "New Rules" by Dua Lipa...
# Done.
# Searching for "Look What You Made Me Do" by Taylor Swift...
# Error fetching lyrics for 'Look What You Made Me Do' by Taylor Swift: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Too Good At Goodbyes" by Sam Smith...
# Done.
# Searching for "Sign of the Times" by Harry Styles...
# Done.
# Searching for "Malibu" by Miley Cyrus...
# Error fetching lyrics for 'Malibu' by Miley Cyrus: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "There's Nothing Holdin' Me Back" by Shawn Mendes...
# Done.
# Searching for "Castle on the Hill" by Ed Sheeran...
# Done.
# Searching for "no tears left to cry" by Ariana Grande...
# Done.
# Searching for "IDGAF" by Dua Lipa...
# Done.
# Searching for "Dancing" by Kylie Minogue...
# Done.
# Searching for "God is a woman" by Ariana Grande...
# Done.
# Batch 101 to 200 processed and saved.
#
# Processing batch 201 to 300...
# Searching for "In My Blood" by Shawn Mendes...
# Done.
# Searching for "Perfect" by Ed Sheeran...
# Done.
# Searching for "Havana" by Camila Cabello...
# Done.
# Searching for "Attention" by Charlie Puth...
# Error fetching lyrics for 'Attention' by Charlie Puth: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Beautiful Trauma" by P!nk...
# Done.
# Searching for "Swish Swish" by Katy Perry...
# Done.
# Searching for "Meant to Be" by Bebe Rexha...
# Done.
# Searching for "bad guy" by Billie Eilish...
# Done.
# Searching for "7 rings" by Ariana Grande...
# Done.
# Searching for "You Need To Calm Down" by Taylor Swift...
# Done.
# Searching for "Señorita" by Shawn Mendes...
# Done.
# Searching for "Truth Hurts" by Lizzo...
# Done.
# Searching for "Without Me" by Halsey...
# Done.
# Searching for "Talk" by Khalid...
# Done.
# Searching for "Don't Start Now" by Dua Lipa...
# Done.
# Searching for "Sucker" by Jonas Brothers...
# Done.
# Searching for "thank u, next" by Ariana Grande...
# Error fetching lyrics for 'thank u, next' by Ariana Grande: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "I Don't Care" by Ed Sheeran...
# Done.
# Searching for "How Long" by Charlie Puth...
# Done.
# Searching for "positions" by Ariana Grande...
# Done.
# Searching for "Watermelon Sugar" by Harry Styles...
# Done.
# Searching for "cardigan" by Taylor Swift...
# Done.
# Searching for "Blinding Lights" by The Weeknd...
# Error fetching lyrics for 'Blinding Lights' by The Weeknd: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "everything i wanted" by Billie Eilish...
# Done.
# Searching for "Monster (Shawn Mendes & Justin Bieber)" by Shawn Mendes...
# Done.
# Searching for "Midnight Sky" by Miley Cyrus...
# Done.
# Searching for "34+35" by Ariana Grande...
# Done.
# Searching for "Say So" by Doja Cat...
# Done.
# Searching for "Daisies" by Katy Perry...
# Done.
# Searching for "How Do You Sleep?" by Sam Smith...
# Done.
# Searching for "drivers license" by Olivia Rodrigo...
# Done.
# Searching for "Easy On Me" by Adele...
# Done.
# Searching for "Kiss Me More" by Doja Cat...
# Done.
# Searching for "Bad Habits" by Ed Sheeran...
# Done.
# Searching for "MONTERO (Call Me By Your Name)" by Lil Nas X...
# Done.
# Searching for "Levitating" by Dua Lipa...
# Error fetching lyrics for 'Levitating (feat. DaBaby)' by Dua Lipa: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Peaches" by Justin Bieber...
# Done.
# Searching for "Butter" by BTS...
# Done.
# Searching for "As It Was" by Harry Styles...
# Done.
# Searching for "Happier Than Ever" by Billie Eilish...
# Done.
# Searching for "Save Your Tears (Remix)" by The Weeknd...
# Done.
# Searching for "Broken Horses" by Brandi Carlile...
# Done.
# Searching for "Late Night Talking" by Harry Styles...
# Done.
# Searching for "About Damn Time" by Lizzo...
# Done.
# Searching for "Oh My God" by Adele...
# Done.
# Searching for "good 4 u" by Olivia Rodrigo...
# Done.
# Searching for "Shivers" by Ed Sheeran...
# Done.
# Searching for "When I’m Gone" by Alesso...
# Done.
# Searching for "Need to Know" by Doja Cat...
# Done.
# Searching for "Flowers" by Miley Cyrus...
# Done.
# Searching for "Anti-Hero" by Taylor Swift...
# Done.
# Searching for "Beg for You" by Charli xcx...
# Done.
# Searching for "2 Be Loved (Am I Ready)" by Lizzo...
# Done.
# Searching for "vampire" by Olivia Rodrigo...
# Done.
# Searching for "River" by Miley Cyrus...
# Done.
# Searching for "Padam Padam" by Kylie Minogue...
# Done.
# Searching for "Waking Up Dreaming" by Shania Twain...
# Done.
# Searching for "Cruel Summer" by Taylor Swift...
# Done.
# Searching for "I'm Not Here To Make Friends" by Sam Smith...
# Done.
# Searching for "we can't be friends (wait for your love)" by Ariana Grande...
# Done.
# Searching for "Rush" by Troye Sivan...
# Done.
# Searching for "Her" by Megan Thee Stallion...
# Done.
# Searching for "CUFF IT" by Beyoncé...
# Done.
# Searching for "Snow Angel" by Reneé Rapp...
# Done.
# Searching for "Paint The Town Red" by Doja Cat...
# Done.
# Searching for "bad idea right?" by Olivia Rodrigo...
# Done.
# Searching for "The Great War" by Taylor Swift...
# Done.
# Searching for "Golden G String" by Miley Cyrus...
# Done.
# Searching for "Electric - Pokemon 25 Version" by Katy Perry...
# No results found for: 'Electric - Pokemon 25 Version Katy Perry'
# Lyrics not found for 'Electric - Pokemon 25 Version' by Katy Perry. Attempting with original list...
# Fuzzy match found: 'California Gurls' with score 31.11111111111111
# Searching for "California Gurls" by Katy Perry...
# Done.
# Lyrics found using fuzzy match title 'California Gurls'.
# Searching for "What Was I Made For? [From The Motion Picture "Barbie"]" by Billie Eilish...
# Done.
# Searching for "Freaky Deaky" by Tyga...
# Done.
# Searching for "Special" by Lizzo...
# Done.
# Searching for "Eyes Closed" by Ed Sheeran...
# Done.
# Searching for "That's Hilarious" by Charlie Puth...
# Done.
# Searching for "Daylight" by Harry Styles...
# Done.
# Searching for "Love U Like That" by Lauv...
# Done.
# Searching for "Everywhere" by Michelle Branch...
# Done.
# Searching for "Love You Like A Love Song" by Selena Gomez & The Scene...
# Done.
# Searching for "Kings & Queens" by Ava Max...
# Done.
# Searching for "you broke me first" by Tate McRae...
# Done.
# Searching for "Our Song" by Anne-Marie...
# Done.
# Searching for "Nonsense" by Sabrina Carpenter...
# Done.
# Searching for "You’re Just A Boy (And I’m Kinda The Man)" by Maisie Peters...
# Done.
# Searching for "Lush Life" by Zara Larsson...
# Done.
# Searching for "Issues" by Julia Michaels...
# Error fetching lyrics for 'Issues' by Julia Michaels: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Heather" by Conan Gray...
# Done.
# Searching for "Heart Wants What It Wants" by Bebe Rexha...
# Done.
# Searching for "Say Yes To Heaven" by Lana Del Rey...
# Done.
# Searching for "Unwritten" by Natasha Bedingfield...
# Done.
# Searching for "Reckless" by Madison Beer...
# Done.
# Searching for "Bubbly" by Colbie Caillat...
# Done.
# Searching for "Hold The Girl" by Rina Sawayama...
# Done.
# Searching for "jar of hearts" by Christina Perri...
# Done.
# Searching for "I'm Yours" by Jason Mraz...
# Done.
# Searching for "Wait for Me" by Daryl Hall & John Oates...
# Done.
# Searching for "Wings" by Little Mix...
# Done.
# Searching for "Breathe Me" by Sia...
# Done.
# Searching for "Dancing On My Own" by Robyn...
# Done.
# Searching for "Lost Cause" by Billie Eilish...
# Done.
# Searching for "Castle" by Halsey...
# Done.
# Batch 201 to 300 processed and saved.
#
# Processing batch 301 to 400...
# Searching for "Californication" by Red Hot Chili Peppers...
# Done.
# Searching for "It's My Life" by Bon Jovi...
# Done.
# Searching for "Kryptonite" by 3 Doors Down...
# Done.
# Searching for "With Arms Wide Open" by Creed...
# Done.
# Searching for "The Middle" by Jimmy Eat World...
# Done.
# Searching for "Smooth Criminal" by Alien Ant Farm...
# Done.
# Searching for "My Generation" by Limp Bizkit...
# Done.
# Searching for "One Last Breath" by Creed...
# Done.
# Searching for "Take A Look Around" by Limp Bizkit...
# Done.
# Searching for "Alive - Chris Lord-Alge Mix" by P.O.D....
# No results found for: 'Alive - Chris Lord-Alge Mix P.O.D.'
# Lyrics not found for 'Alive - Chris Lord-Alge Mix' by P.O.D.. Attempting with original list...
# Fuzzy match found: 'Alive' with score 31.25
# Searching for "Alive" by P.O.D....
# Done.
# Lyrics found using fuzzy match title 'Alive'.
# Searching for "Sacrifice" by Elton John...
# Done.
# Searching for "Get Free" by The Vines...
# Done.
# Searching for "No One Knows" by Queens of the Stone Age...
# Done.
# Searching for "How You Remind Me" by Nickelback...
# Done.
# Searching for "Last Resort" by Papa Roach...
# Done.
# Searching for "Clocks" by Coldplay...
# Done.
# Searching for "Rollin' (Air Raid Vehicle)" by Limp Bizkit...
# Done.
# Searching for "For Whom The Bell Tolls - Remastered" by Metallica...
# Done.
# Searching for "Edge of Seventeen - 2016 Remaster" by Stevie Nicks...
# Done.
# Searching for "In the End" by Linkin Park...
# Error fetching lyrics for 'In the End' by Linkin Park: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Take Me Out" by Franz Ferdinand...
# Done.
# Searching for "Somewhere I Belong" by Linkin Park...
# Done.
# Searching for "Crawl" by Breaking Benjamin...
# Done.
# Searching for "Hanging By A Moment" by Lifehouse...
# Done.
# Searching for "Farmhouse" by Phish...
# Done.
# Searching for "The Way You Like It" by Adema...
# Done.
# Searching for "The Scientist" by Coldplay...
# Done.
# Searching for "Here Without You" by 3 Doors Down...
# Done.
# Searching for "My Sacrifice" by Creed...
# Done.
# Searching for "Aerials" by System Of A Down...
# Done.
# Searching for "By the Way" by Red Hot Chili Peppers...
# Done.
# Searching for "This Is a Call" by Foo Fighters...
# Done.
# Searching for "Stuck In A Moment You Can't Get Out Of" by U2...
# Done.
# Searching for "I'm A Pirate, You're A Princess" by PlayRadioPlay!...
# Done.
# Searching for "The Rising" by Bruce Springsteen...
# Done.
# Searching for "Go With The Flow" by Queens of the Stone Age...
# Done.
# Searching for "Seven Nation Army" by The White Stripes...
# Done.
# Searching for "Here It Goes Again" by OK Go...
# Done.
# Searching for "Get Right" by Jennifer Lopez...
# Done.
# Searching for "Someday" by The Strokes...
# Done.
# Searching for "The Kill (Bury Me)" by Thirty Seconds To Mars...
# Done.
# Searching for "Starlight" by Muse...
# Done.
# Searching for "Times Like These" by Foo Fighters...
# Done.
# Searching for "I Believe in a Thing Called Love" by The Darkness...
# Done.
# Searching for "Chop Suey!" by System Of A Down...
# Done.
# Searching for "Make A Move" by Incubus...
# Done.
# Searching for "Breathe" by The Prodigy...
# Done.
# Searching for "Beautiful Day" by U2...
# Done.
# Searching for "Painkiller" by Three Days Grace...
# Done.
# Searching for "Ride" by The Vines...
# Done.
# Searching for "The Hand That Feeds" by Nine Inch Nails...
# Done.
# Searching for "Somebody Told Me" by The Killers...
# Done.
# Searching for "Best of You" by Foo Fighters...
# Done.
# Searching for "I Miss You" by blink-182...
# Done.
# Searching for "Rise Above This" by Seether...
# Done.
# Searching for "American Idiot" by Green Day...
# Done.
# Searching for "I Don't Wanna Be In Love (Dance Floor Anthem)" by Good Charlotte...
# Done.
# Searching for "Boulevard of Broken Dreams" by Green Day...
# Done.
# Searching for "Harder To Breathe" by Maroon 5...
# Done.
# Searching for "Take a Bow" by Muse...
# Done.
# Searching for "The Reason" by Hoobastank...
# Done.
# Searching for "Gotta Be Somebody - Live From Nashville" by Nickelback...
# Specified song does not contain lyrics. Rejecting.
# Lyrics not found for 'Gotta Be Somebody - Live From Nashville' by Nickelback. Attempting with original list...
# Fuzzy match found: 'Be Somebody' with score 43.99999999999999
# Searching for "Be Somebody" by Nickelback...
# Done.
# Lyrics found using fuzzy match title 'Be Somebody'.
# Searching for "I Don't Care" by Apocalyptica...
# Done.
# Searching for "Animal I Have Become" by Three Days Grace...
# Done.
# Searching for "Fall to Pieces" by Velvet Revolver...
# Done.
# Searching for "Speed of Sound" by Coldplay...
# Done.
# Searching for "Welcome To The Jungle" by Guns N' Roses...
# Done.
# Searching for "Face Down" by The Red Jumpsuit Apparatus...
# Done.
# Searching for "Take The Power Back" by Rage Against The Machine...
# Done.
# Searching for "Earth Intruders" by Björk...
# Done.
# Searching for "What I've Done" by Linkin Park...
# Done.
# Searching for "Welcome to the Black Parade" by My Chemical Romance...
# Done.
# Searching for "Icky Thump" by The White Stripes...
# Done.
# Searching for "How to Save a Life" by The Fray...
# Done.
# Searching for "I Write Sins Not Tragedies" by Panic! At The Disco...
# Done.
# Searching for "The Pretender" by Foo Fighters...
# Done.
# Searching for "Be Yourself" by Audioslave...
# Done.
# Searching for "Save Me" by Shinedown...
# Done.
# Searching for "Photograph - Live From Nashville" by Nickelback...
# Specified song does not contain lyrics. Rejecting.
# Lyrics not found for 'Photograph - Live From Nashville' by Nickelback. Attempting with original list...
# Fuzzy match found: 'Photograph' with score 47.61904761904761
# Searching for "Photograph" by Nickelback...
# Done.
# Lyrics found using fuzzy match title 'Photograph'.
# Searching for "My Curse" by Killswitch Engage...
# Done.
# Searching for "Numb / Encore" by JAY-Z...
# Done.
# Searching for "Chasing Cars" by Snow Patrol...
# Done.
# Searching for "Sweet Sacrifice" by Evanescence...
# Done.
# Searching for "Little Sister" by Queens of the Stone Age...
# Done.
# Searching for "Lost!" by Coldplay...
# Done.
# Searching for "That's What You Get" by Paramore...
# Done.
# Searching for "Sex on Fire" by Kings of Leon...
# Done.
# Searching for "First Date" by blink-182...
# Done.
# Searching for "Decode - Twilight Soundtrack Version" by Paramore...
# No results found for: 'Decode - Twilight Soundtrack Version Paramore'
# Lyrics not found for 'Decode - Twilight Soundtrack Version' by Paramore. Attempting with original list...
# Fuzzy match found: 'That's What You Get' with score 29.09090909090909
# Searching for "That's What You Get" by Paramore...
# Done.
# Lyrics found using fuzzy match title 'That's What You Get'.
# Searching for "Rockstar - 2020 Remaster" by Nickelback...
# No results found for: 'Rockstar - 2020 Remaster Nickelback'
# Lyrics not found for 'Rockstar - 2020 Remaster' by Nickelback. Attempting with original list...
# Fuzzy match found: 'Rockstar' with score 50.0
# Searching for "Rockstar" by Nickelback...
# Done.
# Lyrics found using fuzzy match title 'Rockstar'.
# Searching for "Time Is On My Side - Mono Version / Organ Intro" by The Rolling Stones...
# Done.
# Searching for "Ruby" by Kaiser Chiefs...
# Done.
# Searching for "Fake It" by Seether...
# Done.
# Searching for "This Is How a Heart Breaks" by Rob Thomas...
# Done.
# Searching for "Black Horse And The Cherry Tree" by KT Tunstall...
# Done.
# Searching for "Violet Hill" by Coldplay...
# Done.
# Searching for "21 Guns" by Green Day...
# Done.
# Searching for "All Summer Long" by Kid Rock...
# Done.
# Searching for "Let It Die" by Three Days Grace...
# Done.
# Searching for "Rock And Roll Queen - Alex Sauvage Remix" by The Subways...
# Done.
# Batch 301 to 400 processed and saved.
#
# Processing batch 401 to 500...
# Searching for "Crack The Shutters" by Snow Patrol...
# Done.
# Searching for "I Will Possess Your Heart" by Death Cab for Cutie...
# Done.
# Searching for "Metal Heart" by Accept...
# Done.
# Searching for "Believe" by The Bravery...
# Done.
# Searching for "New Divide" by Linkin Park...
# Done.
# Searching for "Sour Girl" by Stone Temple Pilots...
# Done.
# Searching for "Inside the Fire" by Disturbed...
# Done.
# Searching for "The Climb" by Miley Cyrus...
# Done.
# Searching for "Use Somebody" by Kings of Leon...
# Done.
# Searching for "No Surprise" by Daughtry...
# Done.
# Searching for "Crack the Skye" by Mastodon...
# Done.
# Searching for "Second Chance" by Shinedown...
# Done.
# Searching for "As I Am" by The Goo Goo Dolls...
# Done.
# Searching for "The Shock Of The Lightning" by Oasis...
# Done.
# Searching for "She's so Mean" by Matchbox Twenty...
# Done.
# Searching for "World so Cold" by Three Days Grace...
# Done.
# Searching for "The Good Life" by Three Days Grace...
# Done.
# Searching for "Knives and Pens" by Black Veil Brides...
# Done.
# Searching for "The Catalyst" by Linkin Park...
# Done.
# Searching for "Wasted Years - 2015 Remaster" by Iron Maiden...
# Done.
# Searching for "Howlin' for You" by The Black Keys...
# Done.
# Searching for "Radioactive" by Imagine Dragons...
# Done.
# Searching for "Dog Days Are Over" by Florence + The Machine...
# Done.
# Searching for "Tighten Up" by The Black Keys...
# Done.
# Searching for "No Surrender" by Bruce Springsteen...
# Done.
# Searching for "The Ghost of You" by My Chemical Romance...
# Done.
# Searching for "Kingdom Of Rust" by Doves...
# Done.
# Searching for "Greek Tragedy" by The Wombats...
# Error fetching lyrics for 'Greek Tragedy' by The Wombats: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Sometime Around Midnight" by The Airborne Toxic Event...
# Done.
# Searching for "Roll Away Your Stone" by Mumford & Sons...
# Done.
# Searching for "If I Had a Heart" by Fever Ray...
# Done.
# Searching for "The Sound of Winter" by Bush...
# Done.
# Searching for "Not Your Fault" by AWOLNATION...
# Done.
# Searching for "Take Me To Church" by Hozier...
# Error fetching lyrics for 'Take Me To Church' by Hozier: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Pumped Up Kicks" by Foster The People...
# Done.
# Searching for "Resistance" by Muse...
# Done.
# Searching for "The Cave" by Mumford & Sons...
# Done.
# Searching for "505" by Arctic Monkeys...
# Done.
# Searching for "Lonely Boy" by The Black Keys...
# Done.
# Searching for "The Ocean" by Mike Perry...
# Done.
# Searching for "Runaways" by The Killers...
# Done.
# Searching for "You Can't Always Get What You Want" by The Rolling Stones...
# Done.
# Searching for "Youth of the Nation" by P.O.D....
# Done.
# Searching for "No One Like You (2015 - Remaster)" by Scorpions...
# Done.
# Searching for "I Will Wait" by Mumford & Sons...
# Done.
# Searching for "Little Monster" by Royal Blood...
# Done.
# Searching for "Stubborn Love" by The Lumineers...
# Done.
# Searching for "Helter Skelter - Live" by U2...
# Done.
# Searching for "The Fighter" by Gym Class Heroes...
# Done.
# Searching for "Runaway" by Linkin Park...
# Done.
# Searching for "Blue Veins" by The Raconteurs...
# Done.
# Searching for "Some Nights" by fun....
# Done.
# Searching for "For the First Time" by The Script...
# Done.
# Searching for "Do I Wanna Know?" by Arctic Monkeys...
# Done.
# Searching for "Demons" by Imagine Dragons...
# Done.
# Searching for "Best Day Of My Life" by American Authors...
# Done.
# Searching for "The Phoenix" by Fall Out Boy...
# Done.
# Searching for "Pompeii" by Bastille...
# Done.
# Searching for "All The Pretty Girls" by fun....
# Done.
# Searching for "Once in a Lifetime" by Landon Austin...
# Done.
# Searching for "The Way You Used To Do" by Queens of the Stone Age...
# Done.
# Searching for "Song 2 - 2012 Remaster" by Blur...
# Done.
# Searching for "Otherside" by Red Hot Chili Peppers...
# Done.
# Searching for "Unfinished Sympathy - 2012 Mix/Master" by Massive Attack...
# Done.
# Searching for "Hero Of War" by Rise Against...
# Done.
# Searching for "Let Me Down Easy" by Paolo Nutini...
# Done.
# Searching for "Figure It Out" by Royal Blood...
# Done.
# Searching for "Lullaby - Remastered" by The Cure...
# Done.
# Searching for "Fever Tree" by The Black Keys...
# Done.
# Searching for "Coming Home" by Leon Bridges...
# Done.
# Searching for "Ghosts" by The Head And The Heart...
# Done.
# Searching for "The Wanderer" by U2...
# Done.
# Searching for "Ain't It Fun" by Paramore...
# Done.
# Searching for "My Body - 2020 Remaster" by Young the Giant...
# Done.
# Searching for "Satellite" by Rise Against...
# Done.
# Searching for "Last Hope" by Paramore...
# Done.
# Searching for "I Wanna Get Better" by Bleachers...
# Done.
# Searching for "Renegades" by X Ambassadors...
# Done.
# Searching for "Hail to the King" by Avenged Sevenfold...
# Done.
# Searching for "The Mountain" by Three Days Grace...
# Done.
# Searching for "Ex's & Oh's" by Elle King...
# Done.
# Searching for "Stressed Out" by Twenty One Pilots...
# Done.
# Searching for "Gotta Get Away" by The Offspring...
# Done.
# Searching for "Paint It, Black" by The Rolling Stones...
# Done.
# Searching for "Gimme Shelter" by The Rolling Stones...
# Done.
# Searching for "Heroes - 2017 Remaster" by David Bowie...
# Done.
# Searching for "Kings" by Tribe Society...
# Done.
# Searching for "Smoke And Mirrors" by Imagine Dragons...
# Done.
# Searching for "The Sound of Silence - CYRIL Remix" by Disturbed...
# Done.
# Searching for "Go To War" by NOTHING MORE...
# Done.
# Searching for "Heathens" by Twenty One Pilots...
# Done.
# Searching for "Highway Tune" by Greta Van Fleet...
# Done.
# Searching for "The Runner" by Foals...
# Done.
# Searching for "Ain't No Rest For The Wicked - Original Version" by Cage The Elephant...
# Done.
# Searching for "My Name Is Human" by Highly Suspect...
# Done.
# Searching for "Doomsday" by Architects...
# Done.
# Searching for "The Edge Of Glory" by Lady Gaga...
# Done.
# Searching for "Nothing In My Way" by Keane...
# Done.
# Searching for "White Noise" by The Living End...
# Done.
# Searching for "Emotionless" by Red Sun Rising...
# Done.
# Batch 401 to 500 processed and saved.
#
# Processing batch 501 to 600...
# Searching for "Feel It Still" by Portugal. The Man...
# Done.
# Searching for "Run For Cover" by The Killers...
# Done.
# Searching for "Back from the Dead" by Skillet...
# Done.
# Searching for "Everything Now" by Arcade Fire...
# Done.
# Searching for "Rise Up" by Andra Day...
# Done.
# Searching for "The Man" by The Killers...
# Done.
# Searching for "Believer" by Imagine Dragons...
# Done.
# Searching for "And So It Went" by The Pretty Reckless...
# Done.
# Searching for "A Symptom Of Being Human" by Shinedown...
# Done.
# Searching for "Heaven Knows" by The Pretty Reckless...
# Done.
# Searching for "LOST IN THE ECHO" by Linkin Park...
# Done.
# Searching for "My Blood" by Twenty One Pilots...
# Done.
# Searching for "Africa" by Weezer...
# Done.
# Searching for "High Hopes" by Panic! At The Disco...
# Done.
# Searching for "Gold on the Ceiling" by The Black Keys...
# Done.
# Searching for "Stars" by Grace Potter & The Nocturnals...
# Done.
# Searching for "Black Magic" by The Amazons...
# Done.
# Searching for "Four Out Of Five" by Arctic Monkeys...
# Done.
# Searching for "Hey Boy Hey Girl" by The Chemical Brothers...
# Done.
# Searching for "Don't Go Away - Remastered" by Oasis...
# Done.
# Searching for "The Greatest Show" by Panic! At The Disco...
# Done.
# Searching for "Little Dark Age" by MGMT...
# Done.
# Searching for "Edge Of Darkness" by Greta Van Fleet...
# Done.
# Searching for "Broken Bones" by KALEO...
# Done.
# Searching for "Ghost Of You" by 5 Seconds of Summer...
# Done.
# Searching for "Pressure and Time" by Rival Sons...
# Done.
# Searching for "Back In Black" by AC/DC...
# Done.
# Searching for "Take Me Down" by The Pretty Reckless...
# Done.
# Searching for "Fear Inoculum" by TOOL...
# Done.
# Searching for "Heart Out" by The 1975...
# Done.
# Searching for "Bad Liar" by Imagine Dragons...
# Done.
# Searching for "You Only Live Once" by The Strokes...
# Done.
# Searching for "R U Mine?" by Arctic Monkeys...
# Done.
# Searching for "parents" by YUNGBLUD...
# Done.
# Searching for "Sober Up" by AJR...
# Done.
# Searching for "Could Have Been Me" by The Struts...
# Done.
# Searching for "Death by Rock and Roll" by The Pretty Reckless...
# Done.
# Searching for "Making A Fire" by Foo Fighters...
# Done.
# Searching for "Trouble’s Coming" by Royal Blood...
# Done.
# Searching for "Salvation" by Rancid...
# Done.
# Searching for "Doubt It" by The Amazons...
# Done.
# Searching for "No Son Of Mine" by Foo Fighters...
# Done.
# Searching for "Last Nite" by The Strokes...
# Done.
# Searching for "Lost In Yesterday" by Tame Impala...
# Done.
# Searching for "Alligator Blood" by Bring Me The Horizon...
# Done.
# Searching for "I Am the Fire" by Halestorm...
# Done.
# Searching for "Waiting On A War" by Foo Fighters...
# Done.
# Searching for "The Bandit" by Kings of Leon...
# Done.
# Searching for "The Last Man on Earth" by Wolf Alice...
# Done.
# Searching for "Don't Back Down" by Mammoth WVH...
# Done.
# Searching for "Patience" by Tame Impala...
# Done.
# Searching for "Ohms" by Deftones...
# Done.
# Searching for "Dark Necessities" by Red Hot Chili Peppers...
# Done.
# Searching for "A Little Bit of Love" by Weezer...
# Done.
# Searching for "If You Want Love" by NF...
# Done.
# Searching for "My Medicine - Single Version" by The Pretty Reckless...
# Done.
# Searching for "Give It All" by Rise Against...
# Done.
# Searching for "Entropy" by Beach Bunny...
# Done.
# Searching for "Kingslayer" by Bring Me The Horizon...
# Done.
# Searching for "Black Summer" by Red Hot Chili Peppers...
# Done.
# Searching for "Wild Child" by The Black Keys...
# Done.
# Searching for "Madness" by Muse...
# Done.
# Searching for "A Friend Like Me" by The Interrupters...
# Done.
# Searching for "Patient Number 9" by Ozzy Osbourne...
# Done.
# Searching for "I WANNA BE YOUR SLAVE" by Måneskin...
# Done.
# Searching for "You're Somebody Else" by flora cash...
# Done.
# Searching for "Nobody Knows" by The Lumineers...
# Done.
# Searching for "Carrion" by Parkway Drive...
# Done.
# Searching for "Just Another Girl" by The Killers...
# Done.
# Searching for "Freedom Is Free" by Chicano Batman...
# Done.
# Searching for "The Loneliness of the Long Distance Runner - 2015 Remaster" by Iron Maiden...
# Done.
# Searching for "This Is Why" by Paramore...
# Done.
# Searching for "Scar Tissue" by Red Hot Chili Peppers...
# Done.
# Searching for "(Walkin' Thru The) Sleepy City" by The Rolling Stones...
# Done.
# Searching for "All My Life" by Foo Fighters...
# Done.
# Searching for "By Starlight - Remastered 2012" by The Smashing Pumpkins...
# Done.
# Searching for "Because the Night - Live at Nassau Coliseum, Uniondale, NY - December 1980" by Bruce Springsteen...
# No results found for: 'Because the Night - Live at Nassau Coliseum, Uniondale, NY - December 1980 Bruce Springsteen'
# Lyrics not found for 'Because the Night - Live at Nassau Coliseum, Uniondale, NY - December 1980' by Bruce Springsteen. Attempting with original list...
# Fuzzy match found: 'The Rising' with score 16.666666666666664
# Searching for "The Rising" by Bruce Springsteen...
# Done.
# Lyrics found using fuzzy match title 'The Rising'.
# Searching for "Galvanize" by The Chemical Brothers...
# Done.
# Searching for "Can't Stop the Mirror" by Here Are The Facts You Requested...
# Done.
# Searching for "Heat Waves" by Glass Animals...
# Done.
# Searching for "Safari Song" by Greta Van Fleet...
# Done.
# Searching for "Snap Out Of It" by Arctic Monkeys...
# Done.
# Searching for "Human" by The Killers...
# Done.
# Searching for "Walk" by Foo Fighters...
# Done.
# Searching for "Heavy Soul" by The Black Keys...
# Done.
# Searching for "Lights Out" by Royal Blood...
# Done.
# Searching for "Trip Switch" by Nothing But Thieves...
# Done.
# Searching for "Softly Into The Night" by Ezra Muse...
# Done.
# Searching for "Bones" by Imagine Dragons...
# Done.
# Searching for "Just Breathe" by Pearl Jam...
# Done.
# Searching for "Song For The Dead" by Queens of the Stone Age...
# Done.
# Searching for "Drown" by Bring Me The Horizon...
# Done.
# Searching for "Open Your Eyes" by Alter Bridge...
# Done.
# Searching for "When The Curtain Falls" by Greta Van Fleet...
# Done.
# Searching for "Zero - Remastered 2012" by The Smashing Pumpkins...
# No results found for: 'Zero - Remastered 2012 The Smashing Pumpkins'
# Lyrics not found for 'Zero - Remastered 2012' by The Smashing Pumpkins. Attempting with original list...
# Fuzzy match found: 'Zero' with score 30.76923076923077
# Searching for "Zero" by The Smashing Pumpkins...
# Done.
# Lyrics found using fuzzy match title 'Zero'.
# Searching for "Learn to Fly" by Foo Fighters...
# Done.
# Searching for "The Real Slim Shady" by Eminem...
# Done.
# Searching for "Stan" by Eminem...
# Done.
# Searching for "Back That Thang Up" by JUVENILE...
# Done.
# Searching for "Breathe" by Fabolous...
# Done.
# Batch 501 to 600 processed and saved.
#
# Processing batch 601 to 700...
# Searching for "Drop It Like It's Hot" by Snoop Dogg...
# Done.
# Searching for "Still D.R.E." by Dr. Dre...
# Error fetching lyrics for 'Still D.R.E.' by Dr. Dre: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Big Pimpin'" by JAY-Z...
# Error fetching lyrics for 'Big Pimpin'' by JAY-Z: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "21 Questions" by 50 Cent...
# Error fetching lyrics for '21 Questions' by 50 Cent: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Party Up" by DMX...
# Done.
# Searching for "It's Goin' Down" by Yung Joc...
# Done.
# Searching for "Get Ur Freak On" by Missy Elliott...
# Done.
# Searching for "Air Force Ones" by Nelly...
# Done.
# Searching for "Izzo (H.O.V.A.)" by JAY-Z...
# Error fetching lyrics for 'Izzo (H.O.V.A.)' by JAY-Z: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Hate It Or Love It" by The Game...
# Done.
# Searching for "Get Your Roll On" by Big Tymers...
# Done.
# Searching for "Rollout (My Business)" by Ludacris...
# Done.
# Searching for "Family Affair" by Mary J. Blige...
# Done.
# Searching for "The Next Episode" by Dr. Dre...
# Done.
# Searching for "Southern Hospitality (Featuring Pharrell)" by Ludacris...
# Done.
# Searching for "In Da Club" by 50 Cent...
# Error fetching lyrics for 'In Da Club' by 50 Cent: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Oh Boy" by Cam'ron...
# Done.
# Searching for "U Don't Know Me" by T.I....
# Done.
# Searching for "Always On Time" by Ja Rule...
# Done.
# Searching for "Ain't No Doubt" by Mausberg...
# Done.
# Searching for "Let Me Blow Ya Mind" by Eve...
# Done.
# Searching for "The Way I Am" by Eminem...
# Done.
# Searching for "Hot In Herre" by Nelly...
# Done.
# Searching for "Cleanin' Out My Closet" by Eminem...
# Done.
# Searching for "Lose Yourself" by Eminem...
# Done.
# Searching for "Work It" by Missy Elliott...
# Done.
# Searching for "Get Busy" by Sean Paul...
# Done.
# Searching for "We Don't Care" by Kanye West...
# Done.
# Searching for "Thong Song" by Sisqo...
# Done.
# Searching for "What's Your Fantasy (Featuring Shawna)" by Ludacris...
# Done.
# Searching for "Gonna Make You Sweat (Everybody Dance Now)" by C & C Music Factory...
# Done.
# Searching for "Where Is The Love?" by Black Eyed Peas...
# Done.
# Searching for "Stand Up" by Ludacris...
# Done.
# Searching for "Shake That" by Eminem...
# Done.
# Searching for "The Way You Move" by Outkast...
# Done.
# Searching for "Slow Down" by Brand Nubian...
# Done.
# Searching for "U Can't Touch This" by MC Hammer...
# Done.
# Searching for "The Jump Off" by Lil' Kim...
# Done.
# Searching for "Push It" by Salt-N-Pepa...
# Done.
# Searching for "Excuse Me Miss" by JAY-Z...
# Done.
# Searching for "Right Thurr" by Chingy...
# Done.
# Searching for "Get Low" by Lil Jon & The East Side Boyz...
# Done.
# Searching for "Lean Back" by Terror Squad...
# Done.
# Searching for "Violent Crimes" by Kanye West...
# Done.
# Searching for "This Is Why I'm Hot" by MiMS...
# Done.
# Searching for "Overnight Celebrity" by Twista...
# Done.
# Searching for "Turn Off The Light" by Nelly Furtado...
# Done.
# Searching for "Hypnotize - 2014 Remaster" by The Notorious B.I.G....
# Done.
# Searching for "Gold Digger" by Kanye West...
# Done.
# Searching for "Grindin'" by Clipse...
# Done.
# Searching for "Just A Lil Bit" by 50 Cent...
# Done.
# Searching for "Hustlin'" by Rick Ross...
# Done.
# Searching for "Numb / Encore" by JAY-Z...
# Done.
# Searching for "R.I.P." by Jeezy...
# Done.
# Searching for "Erase Your Social" by Lil Uzi Vert...
# Done.
# Searching for "Bump, Bump, Bump" by B2K...
# Done.
# Searching for "Feel Good Inc." by Gorillaz...
# Error fetching lyrics for 'Feel Good Inc.' by Gorillaz: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Like Toy Soldiers" by Eminem...
# Done.
# Searching for "Candy Shop" by 50 Cent...
# Done.
# Searching for "Outta Control - Remix" by 50 Cent...
# Done.
# Searching for "Ridin'" by Chamillionaire...
# Done.
# Searching for "I'm N Luv (Wit a Stripper)" by T-Pain...
# Done.
# Searching for "Touch It" by Busta Rhymes...
# Done.
# Searching for "Money Maker" by Ludacris...
# Done.
# Searching for "Smack That" by Akon...
# Done.
# Searching for "This Is Why I'm Hot" by MiMS...
# Done.
# Searching for "Walk It Out" by Unk...
# Done.
# Searching for "A Bay Bay - Single Version" by Hurricane Chris...
# Done.
# Searching for "Slow Jamz" by Twista...
# Done.
# Searching for "Put Your Hands Up" by DJ Mass...
# Done.
# Searching for "Show Me What You Got" by JAY-Z...
# Error fetching lyrics for 'Show Me What You Got' by JAY-Z: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "My Humps" by Black Eyed Peas...
# Done.
# Searching for "Fergalicious" by Fergie...
# Done.
# Searching for "Stronger" by Kanye West...
# Done.
# Searching for "Crank That (Soulja Boy)" by Soulja Boy...
# Done.
# Searching for "Lollipop" by Lil Wayne...
# Done.
# Searching for "Party Like A Rock Star" by SHOP BOYZ...
# Done.
# Searching for "Break You Off" by The Roots...
# Done.
# Searching for "Superstar" by Lupe Fiasco...
# Done.
# Searching for "Big Things Poppin' (Do It) - Instrumental" by T.I....
# Done.
# Searching for "Make It Rain" by Fat Joe...
# Done.
# Searching for "Let It Go" by Keyshia Cole...
# Done.
# Searching for "The Sweet Escape" by Gwen Stefani...
# Done.
# Searching for "Can't Tell Me Nothing" by Kanye West...
# Done.
# Searching for "A Milli" by Lil Wayne...
# Done.
# Searching for "Love in This Club" by USHER...
# Done.
# Searching for "Swagga Like Us" by T.I....
# Done.
# Searching for "Paper Planes" by M.I.A....
# Done.
# Searching for "Low" by Flo Rida...
# Done.
# Searching for "The Boss" by Rick Ross...
# Done.
# Searching for "Bust It Baby, Pt. 2" by Plies...
# Done.
# Searching for "Dead And Gone" by T.I....
# Done.
# Searching for "Whatever You Like" by T.I....
# Done.
# Searching for "Heartless" by Kanye West...
# Done.
# ...
# Lyrics not found for 'Heater' by Samim. Attempting with original list...
# Fuzzy match found: 'Heater' with score 100.0
# Searching for "Heater" by Samim...
# Specified song does not contain lyrics. Rejecting.
# Lyrics not found for fuzzy match title 'Heater'.
# Searching for "Perfect (Exceeder)" by Mason...
# Done.
# Searching for "Rise Up" by Yves Larock...
# Done.
# Searching for "By Your Side" by Yves Larock...
# Done.
# Searching for "No More Conversations (Mylo Remix Radio Edit)" by Freeform Five...
# Done.
# Searching for "In White Rooms" by Booka Shade...
# Done.
# Searching for "Always" by Ben Nicky...
# Done.
# Searching for "Forever Young" by David Guetta...
# Done.
# Searching for "Just Dance" by Lady Gaga...
# Done.
# Searching for "Together" by Bob Sinclar...
# Done.
# Searching for "4 AM - Adam K & Soha Radio Edit" by Kaskade...
# Done.
# Searching for "Imagination - Tiësto Radio Edit" by JES...
# Done.
# Searching for "You Make Me Feel" by AnnaGrace...
# Done.
# Searching for "Black & Gold - Radio Edit" by Sam Sparro...
# Done.
# Searching for "Close To The Sun" by Lenny B...
# Done.
# Searching for "Medicine - Radio Mix" by Kim Leoni...
# Done.
# Searching for "Break of Dawn - Radio Edit" by Out Of Office...
# Done.
# Searching for "Some Kinda Rush - Radio Edit" by Booty Luv...
# Done.
# Searching for "Light It Up" by Major Lazer...
# Done.
# Searching for "Being in Love" by JJ Flores...
# Done.
# Searching for "Justify - Club Mix" by ATB...
# Done.
# Searching for "Stamp Your Feet" by Donna Summer...
# Done.
# Searching for "Evacuate The Dancefloor - Radio Edit" by Cascada...
# Done.
# Searching for "Memory - Klaas Radio Mix" by Fragma...
# Done.
# Searching for "When Love Takes Over" by David Guetta...
# Done.
# Searching for "Heartbreak (Make Me a Dancer)" by Sophie Ellis-Bextor...
# Done.
# Searching for "Scared Of Me" by Fedde Le Grand...
# Done.
# Searching for "Fine Print" by Nadia Ali...
# Done.
# Searching for "Body Rock - Manny Lehman Big Room Dub" by Oceana...
# Done.
# Searching for "Bulletproof" by La Roux...
# Done.
# Searching for "Sexy Bitch" by David Guetta...
# Done.
# Searching for "Million Dollar Bill" by Whitney Houston...
# Done.
# Searching for "Hang On" by Plumb...
# Done.
# Searching for "Paparazzi" by Lady Gaga...
# Done.
# Searching for "Celebration" by Madonna...
# Done.
# Searching for "Take Over Control" by AFROJACK...
# Done.
# Searching for "One - Radio Edit" by Swedish House Mafia...
# Done.
# Batch 1201 to 1300 processed and saved.
#
# Processing batch 1301 to 1400...
# Searching for "Raise Your Weapon" by deadmau5...
# Done.
# Searching for "Seek Bromance - Avicii Vocal Edit" by Tim Berg...
# Done.
# Searching for "We No Speak Americano (Edit)" by Yolanda Be Cool...
# Done.
# Searching for "Not Giving Up On Love - Dash Berlin 4AM Mix" by Armin van Buuren...
# Done.
# Searching for "Hello" by Martin Solveig...
# Done.
# Searching for "The Island, Pt. I (Dawn)" by Pendulum...
# Done.
# Searching for "Club Can't Handle Me" by Flo Rida...
# Done.
# Searching for "Plus L'Time (Stereo Love)" by Léa Zelia...
# No results found for: 'Plus L'Time (Stereo Love) Léa Zelia'
# Lyrics not found for 'Plus L'Time (Stereo Love)' by Léa Zelia. Attempting with original list...
# No matching artist found in original list for 'Plus L'Time (Stereo Love)' by Léa Zelia.
# Searching for "Miami 2 Ibiza - Swedish House Mafia vs. Tinie Tempah" by Swedish House Mafia...
# No results found for: 'Miami 2 Ibiza - Swedish House Mafia vs. Tinie Tempah Swedish House Mafia'
# Lyrics not found for 'Miami 2 Ibiza - Swedish House Mafia vs. Tinie Tempah' by Swedish House Mafia. Attempting with original list...
# Fuzzy match found: 'Save the World' with score 18.181818181818176
# Searching for "Save the World" by Swedish House Mafia...
# Done.
# Lyrics found using fuzzy match title 'Save the World'.
# Searching for "Gettin' Over You" by David Guetta...
# Done.
# Searching for "Commander" by Kelly Rowland...
# Done.
# Searching for "Dynamite" by Taio Cruz...
# Done.
# Searching for "Titanium" by David Guetta...
# Done.
# Searching for "Levels - Radio Edit" by Avicii...
# Done.
# Searching for "Promises" by NERO...
# Done.
# Searching for "Calling (Lose My Mind) - Radio Edit" by Sebastian Ingrosso...
# Done.
# Searching for "Bangarang" by Skrillex...
# Done.
# Searching for "Fade Into Darkness - Vocal Radio Mix" by Avicii...
# Done.
# Searching for "Turn Me On" by David Guetta...
# Done.
# Searching for "Turbulence - Radio Edit" by Laidback Luke...
# Done.
# Searching for "Save The World" by Swedish House Mafia...
# Done.
# Searching for "Pressure - Alesso Remix" by Nadia Ali...
# Done.
# Searching for "Cinema" by Benny Benassi...
# Done.
# Searching for "What A Feeling - Radio Edit" by Alex Gaudino...
# Done.
# Searching for "Night By Night" by Chromeo...
# Done.
# Searching for "Clarity" by Zedd...
# Done.
# Searching for "I Could Be The One (Avicii Vs. Nicky Romero) - Radio Edit" by Avicii...
# Done.
# Searching for "Language" by Porter Robinson...
# Done.
# Searching for "Spectrum" by Zedd...
# Done.
# Searching for "In My Mind - Axwell Radio Edit" by Ivan Gough...
# Done.
# Searching for "Years" by Alesso...
# Done.
# Searching for "City Of Dreams - Radio Edit" by Dirty South...
# Done.
# Searching for "Stranger (Mix Cut) - Kyau & Albert Remix" by Jaytech...
# No results found for: 'Stranger (Mix Cut) - Kyau & Albert Remix Jaytech'
# Lyrics not found for 'Stranger (Mix Cut) - Kyau & Albert Remix' by Jaytech. Attempting with original list...
# No matching artist found in original list for 'Stranger (Mix Cut) - Kyau & Albert Remix' by Jaytech.
# Searching for "The Sky - Club Mix (Mixed)" by Mat Zo...
# Done.
# Searching for "Stay The Night - Featuring Hayley Williams Of Paramore" by Zedd...
# Done.
# Searching for "This Is What It Feels Like" by Armin van Buuren...
# Done.
# Searching for "I Am - Radio Edit" by Sick Individuals...
# Done.
# Searching for "Together We Are" by ARTY...
# Done.
# Searching for "Mammoth" by Dimitri Vegas & Like Mike...
# Specified song does not contain lyrics. Rejecting.
# Lyrics not found for 'Mammoth' by Dimitri Vegas & Like Mike. Attempting with original list...
# No matching artist found in original list for 'Mammoth' by Dimitri Vegas & Like Mike.
# Searching for "Starlight (Could You Be Mine) - Radio Edit" by Don Diablo...
# Done.
# Searching for "Reload - Radio Edit" by Sebastian Ingrosso...
# Done.
# Searching for "If I Lose Myself - Alesso vs OneRepublic" by OneRepublic...
# Done.
# Searching for "Eat Sleep Rave Repeat" by Fatboy Slim...
# Done.
# Searching for "Remember" by Thomas Gold...
# Done.
# Searching for "Blow - Radio Edit" by Martin Solveig...
# Done.
# Searching for "Animals - Radio Edit" by Martin Garrix...
# Done.
# Searching for "Runaway" by Kanye West...
# Done.
# Searching for "I Got U" by Duke Dumont...
# Done.
# Searching for "Gold Skies" by Martin Garrix...
# Done.
# Searching for "Take Me Home" by Cash Cash...
# Done.
# Searching for "Blame" by Calvin Harris...
# Done.
# Searching for "Outside" by Calvin Harris...
# Done.
# Searching for "Waves - Robin Schulz Radio Edit" by Mr. Probz...
# Done.
# Searching for "Dangerous" by David Guetta...
# Done.
# Searching for "Heroes (we could be)" by Alesso...
# Done.
# Searching for "Rather Be" by Clean Bandit...
# Done.
# Searching for "Five More Hours" by Deorro...
# Done.
# Searching for "Find You" by Zedd...
# Done.
# Searching for "Ten Feet Tall" by AFROJACK...
# Done.
# Searching for "Where Are Ü Now" by Jack Ü...
# Done.
# Searching for "Don't Look Down" by Martin Garrix...
# Done.
# Searching for "Something New" by Axwell /\ Ingrosso...
# Done.
# Searching for "Five More Hours" by Deorro...
# Done.
# Searching for "Show Me Love - Quintino Remix" by Sam Feldt...
# Done.
# Searching for "The Only Way Is Up" by Martin Garrix...
# Done.
# Searching for "I Wanna Feel - Radio Edit" by Secondcity...
# Done.
# Searching for "Intoxicated - Radio Edit" by Martin Solveig...
# Done.
# Searching for "You lost that lovin feeling" by Sandro Silva...
# Done.
# Searching for "On My Way" by Axwell /\ Ingrosso...
# Done.
# Searching for "Here With Me" by Marshmello...
# Done.
# Searching for "Gold Dust" by Galantis...
# Done.
# Searching for "Goodbye" by Feder...
# Done.
# Searching for "Innerbloom" by RÜFÜS DU SOL...
# Done.
# Searching for "Cold Water" by Major Lazer...
# Done.
# Searching for "Never Be Like You" by Flume...
# Done.
# Searching for "Alone" by Marshmello...
# Done.
# Searching for "Thief" by Ookay...
# Done.
# Searching for "In the Morning" by ZHU...
# Done.
# Searching for "Shelter" by Porter Robinson...
# Done.
# Searching for "Need You" by Dillon Francis...
# Done.
# Searching for "Imaginary Friends" by deadmau5...
# Specified song does not contain lyrics. Rejecting.
# Lyrics not found for 'Imaginary Friends' by deadmau5. Attempting with original list...
# Fuzzy match found: 'Imaginary Friends' with score 100.0
# Searching for "Imaginary Friends" by deadmau5...
# Specified song does not contain lyrics. Rejecting.
# Lyrics not found for fuzzy match title 'Imaginary Friends'.
# Searching for "Let Me Love You" by DJ Snake...
# Done.
# Searching for "The Matrix" by Eric Prydz...
# Specified song does not contain lyrics. Rejecting.
# Lyrics not found for 'The Matrix' by Eric Prydz. Attempting with original list...
# Fuzzy match found: 'The Matrix' with score 100.0
# Searching for "The Matrix" by Eric Prydz...
# Specified song does not contain lyrics. Rejecting.
# Lyrics not found for fuzzy match title 'The Matrix'.
# Searching for "IN THE REDS" by Cirez D...
# Specified song does not contain lyrics. Rejecting.
# Lyrics not found for 'IN THE REDS' by Cirez D. Attempting with original list...
# Fuzzy match found: 'In The Reds' with score 45.45454545454546
# Searching for "In The Reds" by Cirez D...
# Specified song does not contain lyrics. Rejecting.
# Lyrics not found for fuzzy match title 'In The Reds'.
# Searching for "Beneath with Me" by Kaskade...
# Done.
# Searching for "Feel It" by Good Times Ahead...
# Done.
# Searching for "Something Just Like This" by The Chainsmokers...
# Done.
# Searching for "It Ain't Me" by Kygo...
# Done.
# Searching for "Stay" by Zedd...
# Done.
# Searching for "Paris" by The Chainsmokers...
# Done.
# Searching for "Rockabye" by Clean Bandit...
# Error fetching lyrics for 'Rockabye (feat. Sean Paul & Anne-Marie)' by Clean Bandit: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for "Scared to Be Lonely" by Martin Garrix...
# Done.
# Searching for "Symphony" by Clean Bandit...
# Done.
# Searching for "Slide" by Calvin Harris...
# Done.
# Searching for "2U" by David Guetta...
# Done.
# Searching for "More Than You Know" by Axwell /\ Ingrosso...
# Done.
# Searching for "Tired" by Alan Walker...
# Done.
# Searching for "No Promises" by Cheat Codes...
# Done.
# Searching for "One Kiss" by Calvin Harris...
# Done.
# Searching for "FRIENDS" by Marshmello...
# Done.
# Batch 1301 to 1400 processed and saved.
#
# Processing batch 1401 to 1490...
# Searching for "The Middle" by Zedd...
# Done.
# Searching for "These Days" by Rudimental...
# Done.
# Searching for "Solo" by Clean Bandit...
# Done.
# Searching for "Wolves" by Selena Gomez...
# Done.
# Searching for "Jackie Chan" by Tiësto...
# Done.
# Searching for "Happier" by Marshmello...
# Done.
# Searching for "Rise" by Jonas Blue...
# Done.
# Searching for "Body" by Loud Luxury...
# Done.
# Searching for "Silence" by Marshmello...
# Done.
# Searching for "Flames" by David Guetta...
# Done.
# Searching for "Taki Taki" by DJ Snake...
# Done.
# Searching for "Let Me Go" by Hailee Steinfeld...
# Done.
# Searching for "Promises" by Calvin Harris...
# Done.
# Searching for "SOS" by Avicii...
# Done.
# Searching for "Used To Love" by Martin Garrix...
# Done.
# Searching for "No Sleep" by Martin Garrix...
# Done.
# Searching for "Hold On" by Martin Garrix...
# Done.
# Searching for "The One" by The Chainsmokers...
# Done.
# Searching for "I Found U" by Passion Pit...
# Done.
# Searching for "Carry On (from the Original Motion Picture "POKÉMON Detective Pikachu")" by Kygo...
# No results found for: 'Carry On (from the Original Motion Picture "POKÉMON Detective Pikachu") Kygo'
# Lyrics not found for 'Carry On (from the Original Motion Picture "POKÉMON Detective Pikachu")' by Kygo. Attempting with original list...
# No matching artist found in original list for 'Carry On (from the Original Motion Picture "POKÉMON Detective Pikachu")' by Kygo.
# Searching for "Beautiful Now" by Zedd...
# Done.
# Searching for "Never Be Alone" by David Guetta...
# Done.
# Searching for "Piece Of Your Heart" by MEDUZA...
# Done.
# Searching for "Graveyard" by Halsey...
# Done.
# Searching for "Good Things Fall Apart" by ILLENIUM...
# Done.
# Searching for "Take Me Into Space" by Dada Life...
# Done.
# Searching for "Forever Yours - Avicii Tribute" by Kygo...
# Done.
# Searching for "Nightlight" by ILLENIUM...
# Done.
# Searching for "On My Mind" by Diplo...
# Done.
# Searching for "Lose Somebody" by Kygo...
# Done.
# Searching for "Alone, Pt. II" by Alan Walker...
# Done.
# Searching for "OK Not To Be OK" by Marshmello...
# Done.
# Searching for "Lay Your Head On Me" by Major Lazer...
# Done.
# Searching for "You Know You Like It" by DJ Snake...
# Done.
# Searching for "Roses - Imanbek Remix" by SAINt JHN...
# Done.
# Searching for "Kill Me Slow" by David Guetta...
# Done.
# Searching for "Midnight (The Hanging Tree)" by HOSH...
# Done.
# Searching for "Bad" by Don Diablo...
# Done.
# Searching for "Back To U" by SLANDER...
# Done.
# Searching for "Heading South" by Zach Bryan...
# Done.
# Searching for "Post Malone" by Sam Feldt...
# Done.
# Searching for "Your Love (9PM)" by ATB...
# Done.
# Searching for "Don't Be Shy" by Tiësto...
# Done.
# Searching for "The Business" by Tiësto...
# Done.
# Searching for "STAY" by The Kid LAROI...
# Done.
# Searching for "Glitch In The Simulation" by Gryffin...
# Done.
# Searching for "How You Love Me" by 3LAU...
# Done.
# Searching for "Lovefool" by twocolors...
# Done.
# Searching for "Cold Heart - PNAU Remix" by Elton John...
# Done.
# Searching for "Rain On Me" by Lady Gaga...
# Done.
# Searching for "Pepas" by Farruko...
# Done.
# Searching for "In Da Getto" by J Balvin...
# Done.
# Searching for "My Universe" by Coldplay...
# Done.
# Searching for "MAMI" by Chris Lorenzo...
# Done.
# Searching for "Every Time" by Seven Lions...
# Done.
# Searching for "Delilah (pull me out of this)" by Fred again.....
# Done.
# Searching for "The Last Goodbye" by ODESZA...
# Done.
# Searching for "Heaven Takes You Home" by Swedish House Mafia...
# Done.
# Searching for "Survive" by Lane 8...
# Done.
# Searching for "Miracle Maker" by Dom Dolla...
# Done.
# Searching for "Consciousness - Eric Prydz Remix" by Anyma...
# Done.
# Searching for "Angel 1" by Anyma...
# Specified song does not contain lyrics. Rejecting.
# Lyrics not found for 'Angel 1' by Anyma. Attempting with original list...
# Fuzzy match found: 'Consciousness' with score 19.999999999999996
# Searching for "Consciousness" by Anyma...
# Done.
# Lyrics found using fuzzy match title 'Consciousness'.
# Searching for "The Sign" by Anyma...
# Done.
# Searching for "Drugs From Amsterdam" by Mau P...
# Done.
# Searching for "Grapevine" by Lane 8...
# Done.
# Searching for "Turn On The Lights again.." by Fred again.....
# Done.
# Searching for "Leave Before You Love Me" by Marshmello...
# Done.
# Searching for "Hurricane" by Ofenbach...
# Done.
# Searching for "REMEDY" by Alesso...
# Done.
# Searching for "Words" by Alesso...
# Done.
# Searching for "DON'T YOU WORRY" by Black Eyed Peas...
# Done.
# Searching for "By My Side" by GATTÜSO...
# Done.
# Searching for "Higher Love" by Kygo...
# Done.
# Searching for "Live for the Night" by Krewella...
# Done.
# Searching for "We Are The People" by Martin Garrix...
# Done.
# Searching for "On Again" by Mau P...
# Done.
# Searching for "Shiver" by John Summit...
# Done.
# Searching for "Go Back" by John Summit...
# Done.
# Searching for "Lights Out" by Max Styler...
# Done.
# Searching for "Stay Still" by Le Youth...
# Done.
# Searching for "Roar" by Charlotte de Witte...
# Done.
# Searching for "girl$" by Dom Dolla...
# Done.
# Searching for "VHS RAVE" by Tiësto...
# Done.
# Searching for "Never Be Lonely" by Jax Jones...
# Done.
# Searching for "Fire - Official UEFA EURO 2024 Song" by MEDUZA...
# Done.
# Searching for "Perfect (Exceeder)" by David Guetta...
# Done.
# Searching for "Monster" by Don Diablo...
# Done.
# Searching for "In The Dark" by Armin van Buuren...
# Done.
# Searching for "Ready For Your Love" by Felix Jaehn...
# Done.
# Searching for "Desire" by Calvin Harris...
# Done.
# Batch 1401 to 1490 processed and saved.
#
# All batches processed. Final dataset saved.

# %% [markdown]
# ### RETRYING FOR SONGS WHICH HAD ERROR FETCHING LYRICS

# %%
# retrying for songs where there was error fetching lyrics
import lyricsgenius
import pandas as pd
import time
from rapidfuzz import fuzz, process  # For fuzzy matching

# INITIALIZING GENIUS ACCESS TOKEN
GENIUS_ACCESS_TOKEN = "E2YECdbQN9JzdsNJyftP6-PxA6kG6jzPhWSYceXSZgEi3S1oZVmhjOp6jSXjMTq5" 
genius = lyricsgenius.Genius(GENIUS_ACCESS_TOKEN)
genius.remove_section_headers = True  

# LOADING THE DATASET WITH ERRORS
input_file = "my_SPOTIFY_GENIUS_SONG_DATASET.csv"  
original_list_df = pd.read_csv("C:/Users/Nutan/Downloads/songs.csv", encoding="ISO-8859-1")  

# FUNCTION TO NORMALIZE SONG TITLES
def normalize_title(title):
    # Remove "(feat. artist)" or "(with artist)" and any trailing spaces 
    return title.split(" (feat.")[0].split(" (with")[0].strip()
    
# lOADING DATASET
df = pd.read_csv(input_file)

# FILTERING ROWS WHERE LYRICS FETCHING FAILED
retry_df = df[df['Lyrics'] == "Error fetching lyrics"].copy()

# FUZZY MATCH THRESHOLD
FUZZY_MATCH_THRESHOLD = 10 

# PROCESSING EACH ROW WITH ERROR
print(f"Retrying lyrics fetching for {len(retry_df)} rows with errors...")

for index, row in retry_df.iterrows():
    track_name = row['Track Name']
    artist_name = row['Artist']

    try:
        # NORMALIZING THE TRACK NAME
        normalized_track_name = normalize_title(track_name)
        # FETCHING LYRICS USING SPOTIFY TITLE
        song = genius.search_song(normalized_track_name, artist_name)
        if song:
            df.loc[index, 'Lyrics'] = song.lyrics
            print(f"Lyrics fetched for '{track_name}' by {artist_name}.")
        else:
            print(f"Lyrics not found for '{track_name}' by {artist_name}. Attempting fuzzy match...")

            # FUZZY MATCHING: FINDS THE BEST MATCH IN THE ORIGINAL LIST
            artist_matches = original_list_df[
                original_list_df['Artist'].str.lower() == artist_name.lower()
            ]  # FILTER BY ARTIST
            if not artist_matches.empty:
                best_match = process.extractOne(
                    track_name,  # SEARCH FOR TRACK NAME
                    artist_matches['Track Name'],  # COMPARE AGINST ORIGINAL LIST TRACK NAMES
                    scorer=fuzz.token_sort_ratio
                )

                if best_match and best_match[1] >= FUZZY_MATCH_THRESHOLD:
                    # FUZZY MATCH SUCCESSFUL
                    original_title = best_match[0]
                    print(f"Fuzzy match found: '{original_title}' with score {best_match[1]}")
                    song = genius.search_song(original_title, artist_name)
                    if song:
                        df.loc[index, 'Lyrics'] = song.lyrics
                        print(f"Lyrics fetched using fuzzy match '{original_title}'.")
                    else:
                        df.loc[index, 'Lyrics'] = "Lyrics not found"
                        print(f"Lyrics not found for fuzzy match '{original_title}'.")
                else:
                    df.loc[index, 'Lyrics'] = "Lyrics not found"
                    print(f"No suitable fuzzy match found for '{track_name}' by {artist_name}.")
            else:
                df.loc[index, 'Lyrics'] = "Lyrics not found"
                print(f"No matching artist found in original list for '{track_name}' by {artist_name}.")
    except Exception as e:
        df.loc[index, 'Lyrics'] = "Error fetching lyrics"
        print(f"Error fetching lyrics for '{track_name}' by {artist_name}: {e}")

    # DELAY TO AVOID RATE LIMIT
    time.sleep(0.5)

# SAVING THE UODATED DATASET TO THE SAME CSV
df.to_csv(input_file, index=False)

print(f"Retried lyrics fetching completed. Dataset updated in '{input_file}'.")
# Out:
# Retrying lyrics fetching for 19 rows with errors...
# Searching for "Toxic" by Britney Spears...
# Done.
# Lyrics fetched for 'Toxic' by Britney Spears.
# Searching for "Umbrella" by Rihanna...
# Done.
# Lyrics fetched for 'Umbrella' by Rihanna.
# Searching for "Shake It Off" by Taylor Swift...
# Done.
# Lyrics fetched for 'Shake It Off' by Taylor Swift.
# Searching for "Love Yourself" by Justin Bieber...
# Done.
# Lyrics fetched for 'Love Yourself' by Justin Bieber.
# Searching for "Into You" by Ariana Grande...
# Done.
# Lyrics fetched for 'Into You' by Ariana Grande.
# Searching for "Blinding Lights" by The Weeknd...
# Done.
# Lyrics fetched for 'Blinding Lights' by The Weeknd.
# Searching for "In the End" by Linkin Park...
# Done.
# Lyrics fetched for 'In the End' by Linkin Park.
# Searching for "21 Questions" by 50 Cent...
# Done.
# Lyrics fetched for '21 Questions' by 50 Cent.
# Searching for "Feel Good Inc." by Gorillaz...
# Done.
# Lyrics fetched for 'Feel Good Inc.' by Gorillaz.
# Searching for "Started From the Bottom" by Drake...
# Done.
# Lyrics fetched for 'Started From the Bottom' by Drake.
# Searching for "Hotline Bling" by Drake...
# Done.
# Lyrics fetched for 'Hotline Bling' by Drake.
# Searching for "Panda" by Desiigner...
# Done.
# Lyrics fetched for 'Panda' by Desiigner.
# Searching for "Bad and Boujee" by Migos...
# Done.
# Lyrics fetched for 'Bad and Boujee (feat. Lil Uzi Vert)' by Migos.
# Searching for "XO Tour Llif3" by Lil Uzi Vert...
# Done.
# Lyrics fetched for 'XO Tour Llif3' by Lil Uzi Vert.
# Searching for "Bodak Yellow" by Cardi B...
# Done.
# Lyrics fetched for 'Bodak Yellow' by Cardi B.
# Searching for "Mask Off" by Future...
# Done.
# Lyrics fetched for 'Mask Off' by Future.
# Searching for "God's Plan" by Drake...
# Done.
# Lyrics fetched for 'God's Plan' by Drake.
# Searching for "Survival of the Fittest" by Mobb Deep...
# Done.
# Lyrics fetched for 'Survival of the Fittest' by Mobb Deep.
# Searching for "Blue (Da Ba Dee) - Gabry Ponte Ice Pop Radio" by Eiffel 65...
# No results found for: 'Blue (Da Ba Dee) - Gabry Ponte Ice Pop Radio Eiffel 65'
# Lyrics not found for 'Blue (Da Ba Dee) - Gabry Ponte Ice Pop Radio' by Eiffel 65. Attempting fuzzy match...
# Fuzzy match found: 'Blue (Da Ba Dee)' with score 53.333333333333336
# Searching for "Blue (Da Ba Dee)" by Eiffel 65...
# Done.
# Lyrics fetched using fuzzy match 'Blue (Da Ba Dee)'.
# Retried lyrics fetching completed. Dataset updated in 'my_SPOTIFY_GENIUS_SONG_DATASET.csv'.

# %% [markdown]
# # PART 3: CLEANING THE FETCHED LYRICS

# %%
#clean the lyrics
import pandas as pd
import re

# LOADING THE DATASET
input_file = "my_SPOTIFY_GENIUS_SONG_DATASET.csv"  
spotify_df = pd.read_csv(input_file)

# FUNCTION TO CLEAN THE LYRICS BY REMOVING LINE LABELS AND ANNOTATIONS
def clean_lyrics(lyrics):
    if not lyrics or pd.isna(lyrics):  # HANDLING MISSING OR EMPTY LYRICS
        return lyrics

    # REMOVE THE FIRST LINE IF ITS UNRELATED TEXT
    lyrics_lines = lyrics.split('\n')
    if len(lyrics_lines) > 1:
        lyrics = "\n".join(lyrics_lines[1:]).strip()
    
    # REMOVE SECTION HEADERS LIKE [Chorus], [Verse 1], [Bridge: Artist], etc.
    lyrics = re.sub(r'\[.*?\]', '', lyrics)
    
    # REMOVE TRAILING NUMBER AND 'Embed'IF PRESENT
    lyrics = re.sub(r'\d*Embed$', '', lyrics)
    
    # REMOVE EXTRA WHITESPACE AND NEW LINES
    lyrics = re.sub(r'\n+', '\n', lyrics).strip()
    
    return lyrics

#  APPLYING clean_lyrics function TO THE "Lyrics" COLUMN
if 'Lyrics' in spotify_df.columns:
    spotify_df['Lyrics'] = spotify_df['Lyrics'].apply(lambda x: clean_lyrics(str(x)))
    print("Lyrics cleaned successfully.")
else:
    print("Error: 'Lyrics' column is missing in the dataset.")

# OVERWRITE THE SAME CSV FILE WITH CLEANED LYRICS
spotify_df.to_csv(input_file, index=False)

spotify_df[['Track Name', 'Artist', 'Lyrics']].head(10)
# Out:
# Lyrics cleaned successfully.
#                                           Track Name              Artist  \
# 0                             Oops!...I Did It Again      Britney Spears
# 1  Bye Bye Bye - From Deadpool and Wolverine Soun...              *NSYNC
# 2                                  What a Girl Wants  Christina Aguilera
# 3                                              Candy         Mandy Moore
# 4                                  Shape of My Heart     Backstreet Boys
# 5                       I Think I'm in Love with You     Jessica Simpson
# 6                                              Lucky      Britney Spears
# 7                 Give Me Just One Night (Una Noche)                 98º
# 8                                              Reach              S Club
# 9                           Halfway Around The World             A*Teens
#
#                                               Lyrics
# 0  Mmm, yeah\nYeah, yeah, yeah, yeah, yeah, yeah\...
# 1  Bye, bye, bye\nBye, bye\n♪\nBye, bye\n♪\nI, I'...
# 2  What a girl wants, what a girl needs\nWhatever...
# 3  Give it to me\nOoh, oh\nYeah, yeah, yeah, yeah...
# 4  Hmm, mmmh, yeah, yeah\nBaby, please try to for...
# 5  Yeah, yeah, yeah, yeah\nOh-oh\nOh-oh-oh\nEvery...
# 6  This is a story about a girl named Lucky\nEarl...
# 7  You keep telling me you want me\nHold me close...
# 8  When the world leaves you feeling blue\nYou ca...
# 9  (Halfway around the world)\nHalfway around the...

# %% [markdown]
# # PART 4: PREPROCESSING THE LYRICS COLUMN FOR NLP

# %%
# preprocess the lyrics for nlp
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# DOWNLOAD THE NECESSARY NLTK DATA FILES
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# LOADING THE DATASET WITH LYRICS
spotify_df = pd.read_csv("my_SPOTIFY_GENIUS_SONG_DATASET.csv")

# INITIALIZE NLP TOOLS
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# FUNCTION TO PREPROCESS LYRICS
def preprocess_lyrics(lyrics):
    # LOWERCASE THE TEXT
    lyrics = lyrics.lower()
    
    # REMOVING CONTEXT SPECIFIC NOISE
    lyrics = re.sub(r'\b(oh|yeah|na|la|uh|ah)+\b', '', lyrics)
    
    # REMOVEING PUNCTUATION
    lyrics = re.sub(r'[^\w\s]', '', lyrics)
    
    # TOKENIZEING THE TEXT
    words = word_tokenize(lyrics)
    
    # REMOVEING STOP WORDS AND APPLY LEMMATIZATION
    words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]
    
    # REJOINING WORDS TO FORM THE CLEANED TEXT
    return ' '.join(words)

# APPLYING PREPROCESSING TO THE 'Lyrics' COLUMN
spotify_df['Processed_Lyrics'] = spotify_df['Lyrics'].apply(lambda x: preprocess_lyrics(x) if isinstance(x, str) else "")

# SAVING THE CHANGES
spotify_df.to_csv("my_SPOTIFY_GENIUS_SONG_DATASET.csv", index=False)

spotify_df[['Track Name', 'Artist','Lyrics', 'Processed_Lyrics']].head(10)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Nutan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Nutan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Nutan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                           Track Name              Artist  \
# 0                             Oops!...I Did It Again      Britney Spears
# 1  Bye Bye Bye - From Deadpool and Wolverine Soun...              *NSYNC
# 2                                  What a Girl Wants  Christina Aguilera
# 3                                              Candy         Mandy Moore
# 4                                  Shape of My Heart     Backstreet Boys
# 5                       I Think I'm in Love with You     Jessica Simpson
# 6                                              Lucky      Britney Spears
# 7                 Give Me Just One Night (Una Noche)                 98º
# 8                                              Reach              S Club
# 9                           Halfway Around The World             A*Teens
#
#                                               Lyrics  \
# 0  Mmm, yeah\nYeah, yeah, yeah, yeah, yeah, yeah\...
# 1  Bye, bye, bye\nBye, bye\n♪\nBye, bye\n♪\nI, I'...
# 2  What a girl wants, what a girl needs\nWhatever...
# 3  Give it to me\nOoh, oh\nYeah, yeah, yeah, yeah...
# 4  Hmm, mmmh, yeah, yeah\nBaby, please try to for...
# 5  Yeah, yeah, yeah, yeah\nOh-oh\nOh-oh-oh\nEvery...
# 6  This is a story about a girl named Lucky\nEarl...
# 7  You keep telling me you want me\nHold me close...
# 8  When the world leaves you feeling blue\nYou ca...
# 9  (Halfway around the world)\nHalfway around the...
#
#                                     Processed_Lyrics
# 0  mmm think made believe friend baby might seem ...
# 1  bye bye bye bye bye bye bye im tonight youre p...
# 2  girl want girl need whatever make happy set fr...
# 3  give ooh ooh give ooh ooh give im addicted lov...
# 4  hmm mmmh baby please try forgive stay dont put...
# 5  every time youre near baby get kinda crazy hea...
# 6  story girl named lucky early morning wake knoc...
# 7  keep telling want hold close night know deep i...
# 8  world leaf feeling blue count seems hope dream...
# 9  halfway around world halfway around world half...

# %% [markdown]
# # PART 5: SENTIMENT ANALYISIS OF LYRICS

# %%
#sentiment and sentiment score column
from textblob import TextBlob
import pandas as pd

# FUNCTION TO ANALYZE SENTIMENT AND PROVIDE SENTIMENT SCORE
def analyze_sentiment(text):
    blob = TextBlob(text)
    polarity = blob.sentiment.polarity
    sentiment = "Positive" if polarity > 0 else "Negative" if polarity < 0 else "Neutral"
    return sentiment, polarity

# APPLYING THE SENTIMENT ANALYSIS TO GET BOTH SENTIMENT AND SENTIMENT SCORE
spotify_df[['Sentiment', 'Sentiment Score']] = spotify_df['Processed_Lyrics'].apply(
    lambda x: pd.Series(analyze_sentiment(x) if isinstance(x, str) else ("", 0))
)
spotify_df.to_csv("my_SPOTIFY_GENIUS_SONG_DATASET.csv", index=False)


spotify_df[['Track Name', 'Artist', 'Processed_Lyrics', 'Sentiment', 'Sentiment Score']].head(10)
# Out:
#                                           Track Name              Artist  \
# 0                             Oops!...I Did It Again      Britney Spears
# 1  Bye Bye Bye - From Deadpool and Wolverine Soun...              *NSYNC
# 2                                  What a Girl Wants  Christina Aguilera
# 3                                              Candy         Mandy Moore
# 4                                  Shape of My Heart     Backstreet Boys
# 5                       I Think I'm in Love with You     Jessica Simpson
# 6                                              Lucky      Britney Spears
# 7                 Give Me Just One Night (Una Noche)                 98º
# 8                                              Reach              S Club
# 9                           Halfway Around The World             A*Teens
#
#                                     Processed_Lyrics Sentiment  \
# 0  mmm think made believe friend baby might seem ...  Positive
# 1  bye bye bye bye bye bye bye im tonight youre p...  Negative
# 2  girl want girl need whatever make happy set fr...  Positive
# 3  give ooh ooh give ooh ooh give im addicted lov...  Positive
# 4  hmm mmmh baby please try forgive stay dont put...  Positive
# 5  every time youre near baby get kinda crazy hea...  Positive
# 6  story girl named lucky early morning wake knoc...  Positive
# 7  keep telling want hold close night know deep i...  Negative
# 8  world leaf feeling blue count seems hope dream...  Positive
# 9  halfway around world halfway around world half...  Negative
#
#    Sentiment Score
# 0         0.133514
# 1        -0.062693
# 2         0.361380
# 3         0.060714
# 4         0.090000
# 5         0.203346
# 6         0.217949
# 7        -0.343878
# 8         0.241615
# 9        -0.097436

# %% [markdown]
# # PART 6: KEYWORD ECTRACTION FROM LYRICS

# %%
from keybert import KeyBERT
from sentence_transformers import SentenceTransformer
import pandas as pd

# LOADING DATASET
music_df = spotify_df 

# INITIALIZING THE KeyBERT MODEL (THIS MODEL USES BERT EMBEDDINGS INTERNALLY)
model = KeyBERT('all-MiniLM-L6-v2')

# FUCNTION TO EXTRACT KEYWORDS USING KeyBERT
def extracting_keywords_with_keybert(text, top_n=5):
    keywords = model.extract_keywords(text, top_n=top_n)
    return ", ".join([kw[0] for kw in keywords])

# APPLYING THE KeyBERT KEYWORD EXTRACTION TO MOVIE PLOT COLUMN 
music_df['Extracted_Keywords'] = music_df['Lyrics'].fillna("").apply(extracting_keywords_with_keybert)

# SAVING THE COLUMN TO THE CSV FILE
music_df.to_csv("my_SPOTIFY_GENIUS_SONG_DATASET.csv", index=False)

# DISPLAYING THE EXTRACTED KEYWORDS COLUMN
music_df[['Track Name', 'Lyrics', 'Extracted_Keywords']].head(10)
# Out:
# C:\Users\Nutan\anaconda3\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
#                                           Track Name  \
# 0                             Oops!...I Did It Again
# 1  Bye Bye Bye - From Deadpool and Wolverine Soun...
# 2                                  What a Girl Wants
# 3                                              Candy
# 4                                  Shape of My Heart
# 5                       I Think I'm in Love with You
# 6                                              Lucky
# 7                 Give Me Just One Night (Una Noche)
# 8                                              Reach
# 9                           Halfway Around The World
#
#                                               Lyrics  \
# 0  Mmm, yeah\nYeah, yeah, yeah, yeah, yeah, yeah\...
# 1  Bye, bye, bye\nBye, bye\n♪\nBye, bye\n♪\nI, I'...
# 2  What a girl wants, what a girl needs\nWhatever...
# 3  Give it to me\nOoh, oh\nYeah, yeah, yeah, yeah...
# 4  Hmm, mmmh, yeah, yeah\nBaby, please try to for...
# 5  Yeah, yeah, yeah, yeah\nOh-oh\nOh-oh-oh\nEvery...
# 6  This is a story about a girl named Lucky\nEarl...
# 7  You keep telling me you want me\nHold me close...
# 8  When the world leaves you feeling blue\nYou ca...
# 9  (Halfway around the world)\nHalfway around the...
#
#                          Extracted_Keywords
# 0           dreamin, wishin, fool, aw, love
# 1             byeyou, ain, leave, bye, baby
# 2       girl, christina, needs, love, wants
# 3  craving, sugar, candy, begging, addicted
# 4   thinkin, confession, lookin, stay, door
# 5           love, baby, tellin, think, mind
# 6   actress, hollywood, tears, cries, wakes
# 7         night, una, tu, noche, movimiento
# 8    rainbow, dreams, shining, ocean, stars
# 9         loving, baby, growin, love, world

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1490 entries, 0 to 1489
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Track Name          1490 non-null   object
#  1   Artist              1490 non-null   object
#  2   Album               1490 non-null   object
#  3   Release Year        1490 non-null   int64
#  4   Track Popularity    1490 non-null   int64
#  5   Lyrics              1490 non-null   object
#  6   Processed_Lyrics    1490 non-null   object
#  7   Sentiment           1490 non-null   object
#  8   Sentiment Score     1490 non-null   float64
#  9   Extracted_Keywords  1490 non-null   object
#  10  Dominant Topic      1490 non-null   int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 128.2+ KB
